# %%
import docx_converter as dc
from docx import Document
from bs4 import BeautifulSoup
import os
import os
import shutil
import json
import re
from bs4 import BeautifulSoup
from pathlib import Path
import json
import html_converter as hc

# %%
import importlib

dc = importlib.reload(dc)
# Out:
# {'textAlign': 'left', 'fontSize': '1rem', 'fontWeight': 'normal', 'color': '#000000', 'backgroundColor': '#FFFFFF', 'padding': '8px', 'verticalAlign': 'middle'}

# %%
docx_path = "data/PagesCreekPRO+_FINAL.docx"
output_path = f"app/{os.path.splitext(os.path.basename(docx_path))[0]}"
lua_script = "scripts/pandoc/pandoc_docx_cleanup.lua"
html_path = f"{output_path}/content/content.html"
json_path = f"data/{os.path.basename(output_path)}.json"

# %%
def parse_docx_to_html(docx_path, lua_script, output_path):
    """
    Convert a DOCX file to HTML and output tables and images for use in a web application.
    """
    os.path.splitext(os.path.basename(docx_path))[0]
    compatible_docx_path = f"app/{os.path.splitext(os.path.basename(docx_path))[0]}.docx"

    os.makedirs(output_path, exist_ok=True)
    allowed_alt_texts = ["timeline"]

    os.makedirs(f"{output_path}/{dc.FOLDERS['media']}", exist_ok=True)
    os.makedirs(f"{output_path}/{dc.FOLDERS['data']}", exist_ok=True)
    os.makedirs(f"{output_path}/{dc.FOLDERS['content']}", exist_ok=True)

    dc.check_compatibility(docx_path, compatible_docx_path)

    ## copy index.html to output_path
    shutil.copyfile("scripts/index.html", f"{output_path}/index.html")
    if not os.path.exists(f"{output_path}/js"):
        shutil.copytree("scripts/js", f"{output_path}/js")
    if not os.path.exists(f"{output_path}/css"):
        shutil.copytree("scripts/css", f"{output_path}/css")


    ## Styles

    ## Extract text and table styles
    # DEFAULT_STYLES = dc.extract_styles(compatible_docx_path)
    DEFAULT_STYLES = {
      "headings": {
        "h1": {
          "fontFamily": "Chillax Semibold",
          "fontSize": "1.67rem",
          "color": "#1D426F"
        },
        "h2": {
          "fontFamily": "Chillax Semibold",
          "fontSize": "1.17rem",
          "color": "#1D426F"
        },
        "h3": {
          "fontFamily": "Chillax Medium",
          "fontSize": "1.00rem",
          "color": "#1D426F"
        }
      },
      "body": {
        "p": {
          "fontSize": "0.92rem"
        }
      },
      "lists": {},
      "captions": {
        "caption": {
          "fontSize": "0.83rem",
          "fontStyle": "italic"
        }
      },
      "table": {
        "border": "1px solid black",
        "borderCollapse": "collapse",
        "marginBottom": "12px"
      },
      "th": {
        "fontSize": "0.92rem",
        "textAlign": "left",
        "padding": "5px",
        "verticalAlign": "middle",
        "textAlign": "left"
      },
      "td1": {
        "fontSize": "0.92rem",
        "textAlign": "left",
        "padding": "5px",
        "verticalAlign": "middle",
        "textAlign": "left"
      },
      "td": {
        "fontSize": "0.92rem",
        "textAlign": "left",
        "padding": "5px",
        "verticalAlign": "middle",
        "textAlign": "left"
      }
    }

    ## save to json
    with open(f"{output_path}/{dc.FOLDERS['data']}/styles.json", 'w') as f:
        json.dump(DEFAULT_STYLES, f, indent=2)

    ## Extract table data and formating that differs from the default styles
    tables = dc.extract_table_format(compatible_docx_path, DEFAULT_STYLES)
    ## save to json
    with open(f'{output_path}/{dc.FOLDERS['data']}/tables.json', 'w') as f:
        json.dump(tables, f, indent=2)

    ## End Styles ##
    ## Images ##

    alt_text_map = dc.extract_docx_media(compatible_docx_path, output_path, dc.FOLDERS['media'], allowed_alt_texts)
    print("\n📝 Alt Text to Image Mapping:", alt_text_map)

    keep_images = [value.replace("assets", "media") for _, value in alt_text_map.items()]
    print(f"keep_images: {keep_images}")
    images_dict = {image: {'path_doc': path.replace('assets/', './media/'), 'path': path, 'alt_text': ''} for image, path in alt_text_map.items()}
    print("images_dict: ", images_dict)

    ## START NEW VERSION ##
    image_map = dc.parse_images_with_links_and_captions(compatible_docx_path)
    # Filter images with alt text starting with "keep-"
    keep_image_map = [image for image in image_map if image["alt_text"].startswith("keep-")]
    ## Update figure numbers
    keep_image_map_nums = dc.update_figure_numbers(keep_image_map)
    ## Retrieve image types
    keep_image_map_types = dc.identify_image_type(keep_image_map_nums)
    ## END NEW VERSION ##

    initial_html = dc.convert_docx_to_html(compatible_docx_path, lua_script, keep_images)
    print("HTML with unwanted images removed has been generated.")

    initial_html_clean = dc.remove_empty_paragraphs(initial_html)

    missing_figures = dc.check_for_missing_figures(compatible_docx_path, initial_html_clean)
    if missing_figures:
        for r_id, caption in missing_figures.items():
          print(f"⚠️ WARNING: Missing figure: {caption}")

    # Identify figure captions and their corresponding images
    doc_img_src = [images_dict[img]['path_doc'] for img in images_dict]
    # figure_captions = dc.get_figure_captions(initial_html_clean, doc_img_src)

    figure_captions = dc.retrieve_all_figure_captions(
        docx_path=compatible_docx_path,
        html_content=initial_html_clean,
        doc_img_src=doc_img_src
    )

    print(f"Figure captions: {figure_captions}")
    keep_image_map_types = [
        {**item, 'image_name': os.path.splitext(os.path.basename(item.get('image_file', '')))[0]}
        for item in keep_image_map_types
    ]

    keep_image_map_types_figure_captions = [
        {
            **item,
            **(
                {
                    'figure_caption': dc.clean_figure_caption(fc.figure_caption),
                    'figure_number': fc.figure_number,
                    'figure_number_new': fc.figure_number_new,
                    'figure_caption_new': re.sub(
                        str(fc.figure_number),
                        str(fc.figure_number_new),
                        dc.clean_figure_caption(fc.figure_caption),
                        count=1
                    )
                } if (fc := figure_captions.get(item["image_name"])) else {}
            )
        }
        for item in keep_image_map_types
    ]

    # Remove empty <figure> tags
    # number of <figure> tags before cleaning
    num_figures_before = initial_html_clean.count('<figure>')
    # Remove empty <figure> tags
    html_captions_removed = dc.remove_empty_figures(initial_html_clean)
    # number of <figure> tags after cleaning
    num_figures_after = html_captions_removed.count('<figure>')
    print(f"Number of <figure> tags before cleaning: {num_figures_before}")
    print(f"Number of <figure> tags after cleaning: {num_figures_after}")

    ## Replace img tags with div placeholders
    html_images_replaced = dc.replace_images_with_divs(html_captions_removed, keep_image_map_types_figure_captions)

    ## Remove captions from unwanted figures that weren't apart for a <figure> tag
    html_more_captions_removed = dc.remove_captions_from_unwanted_figures(html_images_replaced)

    ## Update in-text figure references
    html_figure_references_updated = dc.update_in_text_figure_references(html_more_captions_removed, keep_image_map_types_figure_captions)

    ## End Images ##
    ## Tables ##


    # Regular expression to match tables
    table_pattern = re.compile(r'<table.*?</table>', re.DOTALL)

    # Reset the counter to zero before replacing tables
    counter = [0]
    html_tables_id = table_pattern.sub(lambda match: dc.table_replacer(match, counter), html_figure_references_updated)

    ## End Tables ##
    ## Navigation ##

    # # Generate navigation data
    # nav_data = dc.generate_navigation_data(html_tables_id)

    # # Save navigation data to JSON file
    # with open(f"{output_path}/{dc.FOLDERS['data']}/navigation.json", "w", encoding="utf-8") as f:
    #     json.dump(nav_data, f, indent=4)

    # # Embed navigation data placeholder as the first element in the HTML
    # if '<div data-navigation></div>' not in html_tables_id:
    #     content_html = '<div data-navigation></div>\n' + html_tables_id

    # # Embed sub navigation data placeholder in the HTML. Place at the line above the first h2 tag of each section
    # content_html = dc.insert_sub_navigation(content_html, nav_data)

    ## End Navigation ##

    # Save the modified content.html
    with open(f"{output_path}/{dc.FOLDERS['content']}/content.html", "w", encoding="utf-8") as f:
        f.write(html_tables_id)

    print("Navigation JSON file and content placeholder updated successfully!")
    print(f"Conversion complete! HTML file saved as {output_path}.")

    return None

parse_docx_to_html(docx_path, lua_script, output_path)

def parse_html_to_json(html_path: str, json_path: str) -> None:
    # Load the HTML content
    html_content = Path(html_path).read_text(encoding="utf-8")

    soup = BeautifulSoup(html_content, "html.parser")
    json_data = hc.html_convert(soup)

    # Clean the JSON fields
    cleaned_json_data = hc.clean_nested_json(json_data)

    # Save the updated structure
    with open(json_path, "w") as f:
        json.dump(cleaned_json_data, f, indent=2)

parse_html_to_json(html_path, json_path)
# Out:
# Compatible document saved as: app/PagesCreekPRO+_FINAL.docx
# Processing table 1...
# Found a drawing element
# Processing table 2...
# Processing table 3...
# Processing table 4...
# Processing table 5...
# Processing table 6...
# 📂 Creating media folder: app/PagesCreekPRO+_FINAL\assets
# ✅ Moving image: image2.png ➝ app/PagesCreekPRO+_FINAL\assets\image2.png
# ✅ Moving image: image7.png ➝ app/PagesCreekPRO+_FINAL\assets\image7.png
# ✅ Moving image: image15.png ➝ app/PagesCreekPRO+_FINAL\assets\image15.png
# ✅ Moving image: image16.png ➝ app/PagesCreekPRO+_FINAL\assets\image16.png
# ✅ Moving image: image17.png ➝ app/PagesCreekPRO+_FINAL\assets\image17.png
# ✅ Moving image: image18.png ➝ app/PagesCreekPRO+_FINAL\assets\image18.png
# ✅ Moving image: image19.png ➝ app/PagesCreekPRO+_FINAL\assets\image19.png
# ✅ Moving image: image20.png ➝ app/PagesCreekPRO+_FINAL\assets\image20.png
# ✅ Moving image: image22.png ➝ app/PagesCreekPRO+_FINAL\assets\image22.png
# ✅ Moving image: image28.png ➝ app/PagesCreekPRO+_FINAL\assets\image28.png
#
# 📝 Alt Text to Image Mapping: {'image2': 'assets/image2.png', 'image7': 'assets/image7.png', 'image15': 'assets/image15.png', 'image16': 'assets/image16.png', 'image17': 'assets/image17.png', 'image18': 'assets/image18.png', 'image19': 'assets/image19.png', 'image20': 'assets/image20.png', 'image22': 'assets/image22.png', 'image28': 'assets/image28.png'}
# keep_images: ['media/image2.png', 'media/image7.png', 'media/image15.png', 'media/image16.png', 'media/image17.png', 'media/image18.png', 'media/image19.png', 'media/image20.png', 'media/image22.png', 'media/image28.png']
# images_dict:  {'image2': {'path_doc': './media/image2.png', 'path': 'assets/image2.png', 'alt_text': ''}, 'image7': {'path_doc': './media/image7.png', 'path': 'assets/image7.png', 'alt_text': ''}, 'image15': {'path_doc': './media/image15.png', 'path': 'assets/image15.png', 'alt_text': ''}, 'image16': {'path_doc': './media/image16.png', 'path': 'assets/image16.png', 'alt_text': ''}, 'image17': {'path_doc': './media/image17.png', 'path': 'assets/image17.png', 'alt_text': ''}, 'image18': {'path_doc': './media/image18.png', 'path': 'assets/image18.png', 'alt_text': ''}, 'image19': {'path_doc': './media/image19.png', 'path': 'assets/image19.png', 'alt_text': ''}, 'image20': {'path_doc': './media/image20.png', 'path': 'assets/image20.png', 'alt_text': ''}, 'image22': {'path_doc': './media/image22.png', 'path': 'assets/image22.png', 'alt_text': ''}, 'image28': {'path_doc': './media/image28.png', 'path': 'assets/image28.png', 'alt_text': ''}}
# icon
# chart
# chart
# chart
# chart
# icon
# chart
# icon
# icon
# image
# HTML with unwanted images removed has been generated.
# ⚠️ WARNING: Missing figure: {'figure_number': '6', 'caption': 'Figure 6. Slope across the property.', 'img_path': 'media/image8.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '7', 'caption': 'Figure 7. Infrastructure that occurs within and around the Pages Creek property.', 'img_path': 'media/image9.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '8', 'caption': 'Figure 8. State-based mapped tenure of the Pages Creek property.', 'img_path': 'media/image10.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '9', 'caption': 'Figure 9. State-based zoning of the Pages Creek property.', 'img_path': 'media/image11.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '10', 'caption': 'Figure 10. Mapping of Indigenous Land Use Agreements in and native title determinations in and around the Pages Creek property.', 'img_path': 'media/image12.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '11', 'caption': 'Figure 11. Mining tenements and exploration licenses in and around the Pages Creek property.', 'img_path': 'media/image13.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '12', 'caption': 'Figure 12. Existing Clean Energy Regulator carbon projects in and around the Pages Creek property.', 'img_path': 'media/image14.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '13', 'caption': 'Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.', 'img_path': 'media/image15.png', 'alt_text': 'keep-chart-precipitation'}
# ⚠️ WARNING: Missing figure: {'figure_number': '14', 'caption': 'Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', 'img_path': 'media/image16.png', 'alt_text': 'keep-chart-temperature'}
# ⚠️ WARNING: Missing figure: {'figure_number': '15', 'caption': 'Figure 15. Median number of days with temperatures below 0°C since 1956.', 'img_path': 'media/image17.png', 'alt_text': 'keep-chart-frost'}
# ⚠️ WARNING: Missing figure: {'figure_number': '16', 'caption': 'Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', 'img_path': 'media/image19.png', 'alt_text': 'keep-chart-drought'}
# ⚠️ WARNING: Missing figure: {'figure_number': '17', 'caption': 'Figure 17. The bushfire history (prescribed burn and wildfire) in the region surrounding the Pages Creek property. The property boundaries are identified by the white bordered polygons.', 'img_path': 'media/image21.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '18', 'caption': 'Figure 18. The probability of inundation for the region surrounding the Pages Creek property, based on a National Flood Risk Model.', 'img_path': 'media/image23.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '19', 'caption': 'Figure 19. High risk areas of dryland salinity in the region surrounding the Pages Creek property', 'img_path': 'media/image24.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '20', 'caption': 'Figure 20. Mapped Major Vegetation Groups (MVG) within the Pages Creek property', 'img_path': 'media/image25.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '21', 'caption': 'Figure 21. State-based Pre-European vegetation within the Pages Creek property.', 'img_path': 'media/image26.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '22', 'caption': 'Figure 22. Australian Soil Classification mapping within the Pages Creek property.', 'img_path': 'media/image27.png', 'alt_text': ''}
# ⚠️ WARNING: Missing figure: {'figure_number': '23', 'caption': 'Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', 'img_path': 'media/image28.png', 'alt_text': 'keep-image-timeline'}
# ⚠️ WARNING: Number of figure captions does not match number of images in the document.
# Sourcing missing figures from document...
# ⚠️ WARNING: Figure image2 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image18 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image20 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image22 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# Figure captions: {'image7': Image(figure_number=5, figure_number_new=1, figure_caption='Figure 5. Accumulation curve of gross ACCUs generated\r\neach year over the 25-year permanence period. The first recommended\r\nreporting period of the permanence period is illustrated by a yellow\r\nstar.', alt_text='keep-chart-accu_curve'), 'image15': Image(figure_number='13', figure_number_new=2, figure_caption='Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.', alt_text='keep-chart-precipitation'), 'image16': Image(figure_number='14', figure_number_new=3, figure_caption='Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', alt_text='keep-chart-temperature'), 'image17': Image(figure_number='15', figure_number_new=4, figure_caption='Figure 15. Median number of days with temperatures below 0°C since 1956.', alt_text='keep-chart-frost'), 'image19': Image(figure_number='16', figure_number_new=5, figure_caption='Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', alt_text='keep-chart-drought'), 'image28': Image(figure_number='23', figure_number_new=6, figure_caption='Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', alt_text='keep-image-timeline')}
# Number of <figure> tags before cleaning: 5
# Number of <figure> tags after cleaning: 1
# {'image_id': 'rId10', 'image_file': './media/image2.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-material-symbols-outlined:psychiatry', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'material-symbols-outlined', 'icon': 'psychiatry', 'image_name': 'image2'}
# icon
# {'image_id': 'rId15', 'image_file': './media/image7.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-accu_curve', 'figure_number': 5, 'figure_label': None, 'figure_caption': 'Figure 5. Accumulation curve of gross ACCUs generated each year over the 25-year permanence period. The first recommended reporting period of the permanence period is illustrated by a yellow star.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 1, 'image_type': 'chart', 'chart': 'accu_curve', 'image_name': 'image7', 'figure_caption_new': 'Figure 1. Accumulation curve of gross ACCUs generated each year over the 25-year permanence period. The first recommended reporting period of the permanence period is illustrated by a yellow star.'}
# chart
# {'image_id': 'rId23', 'image_file': './media/image15.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-precipitation', 'figure_number': '13', 'figure_label': None, 'figure_caption': 'Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 2, 'image_type': 'chart', 'chart': 'precipitation', 'image_name': 'image15', 'figure_caption_new': 'Figure 2. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.'}
# chart
# Removing caption paragraph after image 2
# {'image_id': 'rId24', 'image_file': './media/image16.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-temperature', 'figure_number': '14', 'figure_label': None, 'figure_caption': 'Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 3, 'image_type': 'chart', 'chart': 'temperature', 'image_name': 'image16', 'figure_caption_new': 'Figure 3. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.'}
# chart
# Removing caption paragraph after image 3
# {'image_id': 'rId25', 'image_file': './media/image17.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-frost', 'figure_number': '15', 'figure_label': None, 'figure_caption': 'Figure 15. Median number of days with temperatures below 0°C since 1956.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 4, 'image_type': 'chart', 'chart': 'frost', 'image_name': 'image17', 'figure_caption_new': 'Figure 4. Median number of days with temperatures below 0°C since 1956.'}
# chart
# Removing caption paragraph after image 4
# {'image_id': 'rId26', 'image_file': './media/image18.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-custom:drought', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'custom', 'icon': 'drought', 'image_name': 'image18'}
# icon
# {'image_id': 'rId27', 'image_file': './media/image19.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-drought', 'figure_number': '16', 'figure_label': None, 'figure_caption': 'Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 5, 'image_type': 'chart', 'chart': 'drought', 'image_name': 'image19', 'figure_caption_new': 'Figure 5. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.'}
# chart
# Removing caption paragraph after image 6
# {'image_id': 'rId28', 'image_file': './media/image20.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-custom:bushfire', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'custom', 'icon': 'bushfire', 'image_name': 'image20'}
# icon
# Removing caption paragraph after image 7
# {'image_id': 'rId30', 'image_file': './media/image22.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-custom:flood', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'custom', 'icon': 'flood', 'image_name': 'image22'}
# icon
# {'image_id': 'rId36', 'image_file': './media/image28.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-image-timeline', 'figure_number': '23', 'figure_label': None, 'figure_caption': 'Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 6, 'image_type': 'image', 'alt_text_new': 'timeline', 'image_name': 'image28', 'figure_caption_new': 'Figure 6. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.'}
# image
# Removing caption paragraph after image 9
# Removing orphaned figure caption: Figure 6. Slope across the property.
# Removing orphaned figure caption: Figure 7. Infrastructure that occurs within and around the Pages
# Creek property.
# Removing orphaned figure caption: Figure 8. State-based mapped tenure of the Pages Creek
# property.
# Removing orphaned figure caption: Figure 9. State-based zoning of the Pages Creek
# property.
# Removing orphaned figure caption: Figure 10. Mapping of Indigenous Land Use Agreements in and
# native title determinations in and around the Pages Creek
# property.
# Removing orphaned figure caption: Figure 11. Mining tenements and exploration licenses in and
# around the Pages Creek property.
# Removing orphaned figure caption: Figure 12. Existing Clean Energy Regulator carbon projects in and
# around the Pages Creek property.
# Removing orphaned figure caption: Figure 18. The probability of inundation for the region
# surrounding the Pages Creek property, based on a National Flood Risk
# Model.
# Removing orphaned figure caption: Figure 19.
# Removing orphaned figure caption: Figure 20. Mapped Major Vegetation Groups (MVG) within the Pages
# Creek property
# Removing orphaned figure caption: Figure 21. State-based Pre-European vegetation within the Pages
# Creek property.
# Removing orphaned figure caption: Figure 22. Australian Soil Classification mapping within the
# Pages Creek property.
# Updating in-text reference: '/ha/year, equivalent to approximately
# 807,776 Australian Carbon Credit Units (ACCUs) when considering the risk
# of reversal buffer for a project registered with a permanence period of
# 25 years (Table 4). A breakdown of ACCU generation can be seen in Table
# 5 and Figure 5.' → '/ha/year, equivalent to approximately
# 807,776 Australian Carbon Credit Units (ACCUs) when considering the risk
# of reversal buffer for a project registered with a permanence period of
# 25 years (Table 4). A breakdown of ACCU generation can be seen in Table
# 5 and Figure 1.'
# Updating in-text reference: 'In the summer months, spanning December, January, and February, the
# mean maximum temperature averages around 26.4°C, while the mean minimum
# temperature is approximately 13.4°C. During the winter months of June,
# July, and August, the mean maximum temperature drops to about 13.1°C,
# and the mean minimum temperature averages approximately 2.3°C (Figure
# 14).' → 'In the summer months, spanning December, January, and February, the
# mean maximum temperature averages around 26.4°C, while the mean minimum
# temperature is approximately 13.4°C. During the winter months of June,
# July, and August, the mean maximum temperature drops to about 13.1°C,
# and the mean minimum temperature averages approximately 2.3°C (Figure 3).'
# Updating in-text reference: 'Days below zero degrees Celsius (indexed by frost days) present as a
# risk towards the establishment and survival of young plants. Long term
# data indicates that frost does not occur in and around the property of
# Pages Creek (Figure 15).' → 'Days below zero degrees Celsius (indexed by frost days) present as a
# risk towards the establishment and survival of young plants. Long term
# data indicates that frost does not occur in and around the property of
# Pages Creek (Figure 4).'
# Updating in-text reference: 'Drought risk around the Pages Creek property is ‘high’. In the past
# 20 years, there have been more severe-to-extreme dry periods when
# compared to very-to-extreme wet periods (Figure 16).' → 'Drought risk around the Pages Creek property is ‘high’. In the past
# 20 years, there have been more severe-to-extreme dry periods when
# compared to very-to-extreme wet periods (Figure 5).'
# Updating in-text reference: 'The development of a carbon project follows several key stages
# summarised in Figure 23.' → 'The development of a carbon project follows several key stages
# summarised in Figure 6.'
# Navigation JSON file and content placeholder updated successfully!
# Conversion complete! HTML file saved as app/PagesCreekPRO+_FINAL.
# Skipping div: <div class="chart" data-caption="Figure 2. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024." id="precipitation"></div>
# Skipping div: <div class="chart" data-caption="Figure 3. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024." id="temperature"></div>
# Skipping div: <div class="chart" data-caption="Figure 4. Median number of days with temperatures below 0°C since 1956." id="frost"></div>
# Found icon div: <div class="icon" data-caption="{{droughtRisk}}" data-icon-name="drought" data-icon-type="custom"></div>
# Skipping div: <div class="chart" data-caption="Figure 5. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property." id="drought"></div>
# Found icon div: <div class="icon" data-caption="{{bushfireRisk}}" data-icon-name="bushfire" data-icon-type="custom"></div>
# Found icon div: <div class="icon" data-caption="{{floodRisk}}" data-icon-name="flood" data-icon-type="custom"></div>
# Skipping div: <div class="image" data-caption="Figure 6. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting." data-src="./assets/timeline.png"></div>

# %% [markdown]
# #### START TESTING

# %%
docx_path = "data/grovia_Carbon-PRO_Template.docx"
output_path = f"app/{os.path.splitext(os.path.basename(docx_path))[0]}"
lua_script = "scripts/pandoc/pandoc_docx_cleanup.lua"

# %%
compatible_docx_path = f"app/{os.path.splitext(os.path.basename(docx_path))[0]}.docx"

os.makedirs(output_path, exist_ok=True)
allowed_alt_texts = ["timeline"]

os.makedirs(f"{output_path}/{dc.FOLDERS['media']}", exist_ok=True)
os.makedirs(f"{output_path}/{dc.FOLDERS['data']}", exist_ok=True)
os.makedirs(f"{output_path}/{dc.FOLDERS['content']}", exist_ok=True)

dc.check_compatibility(docx_path, compatible_docx_path)

## copy index.html to output_path
shutil.copyfile("scripts/index.html", f"{output_path}/index.html")
if not os.path.exists(f"{output_path}/js"):
    shutil.copytree("scripts/js", f"{output_path}/js")
if not os.path.exists(f"{output_path}/css"):
    shutil.copytree("scripts/css", f"{output_path}/css")


## Styles

## Extract text and table styles
# DEFAULT_STYLES = dc.extract_styles(compatible_docx_path)
DEFAULT_STYLES = {
  "headings": {
    "h1": {
      "fontFamily": "Chillax Semibold",
      "fontSize": "1.67rem",
      "color": "#1D426F"
    },
    "h2": {
      "fontFamily": "Chillax Semibold",
      "fontSize": "1.17rem",
      "color": "#1D426F"
    },
    "h3": {
      "fontFamily": "Chillax Medium",
      "fontSize": "1.00rem",
      "color": "#1D426F"
    }
  },
  "body": {
    "p": {
      "fontSize": "0.92rem"
    }
  },
  "lists": {},
  "captions": {
    "caption": {
      "fontSize": "0.83rem",
      "fontStyle": "italic"
    }
  },
  "table": {
    "border": "1px solid black",
    "borderCollapse": "collapse",
    "marginBottom": "12px"
  },
  "th": {
    "fontSize": "0.92rem",
    "textAlign": "left",
    "padding": "5px",
    "verticalAlign": "middle",
    "textAlign": "left"
  },
  "td1": {
    "fontSize": "0.92rem",
    "textAlign": "left",
    "padding": "5px",
    "verticalAlign": "middle",
    "textAlign": "left"
  },
  "td": {
    "fontSize": "0.92rem",
    "textAlign": "left",
    "padding": "5px",
    "verticalAlign": "middle",
    "textAlign": "left"
  }
}

## save to json
with open(f"{output_path}/{dc.FOLDERS['data']}/styles.json", 'w') as f:
    json.dump(DEFAULT_STYLES, f, indent=2)

## Extract table data and formating that differs from the default styles
tables = dc.extract_table_format(compatible_docx_path, DEFAULT_STYLES)
## save to json
with open(f'{output_path}/{dc.FOLDERS['data']}/tables.json', 'w') as f:
    json.dump(tables, f, indent=2)

## End Styles ##
## Images ##

alt_text_map = dc.extract_docx_media(compatible_docx_path, output_path, dc.FOLDERS['media'], allowed_alt_texts)
print("\n📝 Alt Text to Image Mapping:", alt_text_map)

keep_images = [value.replace("assets", "media") for _, value in alt_text_map.items()]
print(f"keep_images: {keep_images}")
images_dict = {image: {'path_doc': path.replace('assets/', './media/'), 'path': path, 'alt_text': ''} for image, path in alt_text_map.items()}
print("images_dict: ", images_dict)

## START NEW VERSION ##
image_map = dc.parse_images_with_links_and_captions(compatible_docx_path)
# Filter images with alt text starting with "keep-"
keep_image_map = [image for image in image_map if image["alt_text"].startswith("keep-")]
## Update figure numbers
keep_image_map_nums = dc.update_figure_numbers(keep_image_map)
## Retrieve image types
keep_image_map_types = dc.identify_image_type(keep_image_map_nums)
## END NEW VERSION ##

initial_html = dc.convert_docx_to_html(compatible_docx_path, lua_script, keep_images)
print("HTML with unwanted images removed has been generated.")

initial_html_clean = dc.remove_empty_paragraphs(initial_html)

# Identify figure captions and their corresponding images
doc_img_src = [images_dict[img]['path_doc'] for img in images_dict]

## Gets figure captions from the HTML content or direct from docx if they are not in HTML content and matches them with the document images
figure_captions = dc.retrieve_all_figure_captions(
    docx_path = compatible_docx_path, 
    html_content = initial_html_clean, 
    doc_img_src = doc_img_src
    )

print(f"Figure captions: {figure_captions}")
keep_image_map_types = [
    {**item, 'image_name': os.path.splitext(os.path.basename(item.get('image_file', '')))[0]}
    for item in keep_image_map_types
]

keep_image_map_types_figure_captions = [
    {
        **item,
        **(
            {
                'figure_caption': dc.clean_figure_caption(fc.figure_caption),
                'figure_number': fc.figure_number,
                'figure_number_new': fc.figure_number_new,
                'figure_caption_new': re.sub(
                    str(fc.figure_number),
                    str(fc.figure_number_new),
                    dc.clean_figure_caption(fc.figure_caption),
                    count=1
                )
            } if (fc := figure_captions.get(item["image_name"])) else {}
        )
    }
    for item in keep_image_map_types
]

# Remove empty <figure> tags
# number of <figure> tags before cleaning
num_figures_before = initial_html_clean.count('<figure>')
# Remove empty <figure> tags
html_captions_removed = dc.remove_empty_figures(initial_html_clean)
# number of <figure> tags after cleaning
num_figures_after = html_captions_removed.count('<figure>')
print(f"Number of <figure> tags before cleaning: {num_figures_before}")
print(f"Number of <figure> tags after cleaning: {num_figures_after}")

## Replace img tags with div placeholders
html_images_replaced = dc.replace_images_with_divs(html_captions_removed, keep_image_map_types_figure_captions)

def remove_captions_from_unwanted_figures(html_content: str) -> None:
  # Pattern to match the start of a figure caption like "Figure 8."
  figure_caption_pattern = re.compile(r"^Figure\s+\d+\.?", re.IGNORECASE)

  soup = BeautifulSoup(html_content, "html.parser")

  # Loop over all <p> tags
  for p in soup.find_all("p"):
      first_em = p.find("em", recursive=False)
      if first_em:
          em_text = first_em.get_text(strip=True)
          if figure_caption_pattern.match(em_text):
              print(f"Removing orphaned figure caption: {em_text}")
              p.decompose()

  return str(soup)


def update_in_text_figure_references(html_content: str, image_mapping: list) -> str:
    """
    Update in-text figure references to match the new figure numbers.
    """
    import re
    from bs4 import NavigableString

    soup = BeautifulSoup(html_content, "html.parser")

    # Build a map from original figure number → new number
    figure_number_map = {
        str(item["figure_number"]): str(item["figure_number_new"])
        for item in image_mapping
        if item.get("figure_number") is not None and item.get("figure_number_new") is not None
    }

    # Regex to find "Figure N"
    figure_ref_pattern = re.compile(r"\bFigure\s+(\d+)\b")

    # Tags to inspect (excluding <div>)
    search_tags = ["p", "li", "span", "td"]

    # Loop through all text nodes in non-div tags
    for tag in soup.find_all(search_tags):
        if tag.find_parent("div"):
            continue  # skip if this tag is inside any <div>

        for descendant in tag.descendants:
            if isinstance(descendant, NavigableString):
                original_text = str(descendant)
                new_text = figure_ref_pattern.sub(
                    lambda m: f"Figure {figure_number_map[m.group(1)]}" if m.group(1) in figure_number_map else m.group(0),
                    original_text
                )
                if new_text != original_text:
                    print(f"Updating in-text reference: '{original_text.strip()}' → '{new_text.strip()}'")
                    descendant.replace_with(new_text)

    return str(soup)

## Remove captions from unwanted figures that weren't apart for a <figure> tag
html_more_captions_removed = remove_captions_from_unwanted_figures(html_images_replaced)

## Update in-text figure references
html_figure_references_updated = update_in_text_figure_references(html_more_captions_removed, keep_image_map_types_figure_captions)


## End Images ##
## Tables ##


# Regular expression to match tables
table_pattern = re.compile(r'<table.*?</table>', re.DOTALL)

# Reset the counter to zero before replacing tables
counter = [0]
html_tables_id = table_pattern.sub(lambda match: dc.table_replacer(match, counter), html_figure_references_updated)


## End Tables ##
## Navigation ##

# # Generate navigation data
# nav_data = dc.generate_navigation_data(html_tables_id)

# # Save navigation data to JSON file
# with open(f"{output_path}/{dc.FOLDERS['data']}/navigation.json", "w", encoding="utf-8") as f:
#     json.dump(nav_data, f, indent=4)

# # Embed navigation data placeholder as the first element in the HTML
# if '<div data-navigation></div>' not in html_tables_id:
#     content_html = '<div data-navigation></div>\n' + html_tables_id

# # Embed sub navigation data placeholder in the HTML. Place at the line above the first h2 tag of each section
# content_html = dc.insert_sub_navigation(content_html, nav_data)

# End Navigation ##

# Save the modified content.html
with open(f"{output_path}/{dc.FOLDERS['content']}/content.html", "w", encoding="utf-8") as f:
    f.write(html_tables_id)

# print("Navigation JSON file and content placeholder updated successfully!")
print(f"Conversion complete! HTML file saved as {output_path}.")
# Out:
# Compatible document saved as: app/PagesCreekPRO+_FINAL.docx
# Processing table 1...
# Found a drawing element
# Processing table 2...
# Processing table 3...
# Processing table 4...
# Processing table 5...
# Processing table 6...
# 📂 Creating media folder: app/PagesCreekPRO+_FINAL\assets
# ✅ Moving image: image2.png ➝ app/PagesCreekPRO+_FINAL\assets\image2.png
# ✅ Moving image: image7.png ➝ app/PagesCreekPRO+_FINAL\assets\image7.png
# ✅ Moving image: image15.png ➝ app/PagesCreekPRO+_FINAL\assets\image15.png
# ✅ Moving image: image16.png ➝ app/PagesCreekPRO+_FINAL\assets\image16.png
# ✅ Moving image: image17.png ➝ app/PagesCreekPRO+_FINAL\assets\image17.png
# ✅ Moving image: image18.png ➝ app/PagesCreekPRO+_FINAL\assets\image18.png
# ✅ Moving image: image19.png ➝ app/PagesCreekPRO+_FINAL\assets\image19.png
# ✅ Moving image: image20.png ➝ app/PagesCreekPRO+_FINAL\assets\image20.png
# ✅ Moving image: image22.png ➝ app/PagesCreekPRO+_FINAL\assets\image22.png
# ✅ Moving image: image28.png ➝ app/PagesCreekPRO+_FINAL\assets\image28.png
#
# 📝 Alt Text to Image Mapping: {'image2': 'assets/image2.png', 'image7': 'assets/image7.png', 'image15': 'assets/image15.png', 'image16': 'assets/image16.png', 'image17': 'assets/image17.png', 'image18': 'assets/image18.png', 'image19': 'assets/image19.png', 'image20': 'assets/image20.png', 'image22': 'assets/image22.png', 'image28': 'assets/image28.png'}
# keep_images: ['media/image2.png', 'media/image7.png', 'media/image15.png', 'media/image16.png', 'media/image17.png', 'media/image18.png', 'media/image19.png', 'media/image20.png', 'media/image22.png', 'media/image28.png']
# images_dict:  {'image2': {'path_doc': './media/image2.png', 'path': 'assets/image2.png', 'alt_text': ''}, 'image7': {'path_doc': './media/image7.png', 'path': 'assets/image7.png', 'alt_text': ''}, 'image15': {'path_doc': './media/image15.png', 'path': 'assets/image15.png', 'alt_text': ''}, 'image16': {'path_doc': './media/image16.png', 'path': 'assets/image16.png', 'alt_text': ''}, 'image17': {'path_doc': './media/image17.png', 'path': 'assets/image17.png', 'alt_text': ''}, 'image18': {'path_doc': './media/image18.png', 'path': 'assets/image18.png', 'alt_text': ''}, 'image19': {'path_doc': './media/image19.png', 'path': 'assets/image19.png', 'alt_text': ''}, 'image20': {'path_doc': './media/image20.png', 'path': 'assets/image20.png', 'alt_text': ''}, 'image22': {'path_doc': './media/image22.png', 'path': 'assets/image22.png', 'alt_text': ''}, 'image28': {'path_doc': './media/image28.png', 'path': 'assets/image28.png', 'alt_text': ''}}
# icon
# chart
# chart
# chart
# chart
# icon
# chart
# icon
# icon
# image
# HTML with unwanted images removed has been generated.
# ⚠️ WARNING: Number of figure captions does not match number of images in the document.
# Sourcing missing figures from document...
# ⚠️ WARNING: Figure image2 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image18 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image20 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image22 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# Figure captions: {'image7': Image(figure_number=5, figure_number_new=1, figure_caption='Figure 5. Accumulation curve of gross ACCUs generated\r\neach year over the 25-year permanence period. The first recommended\r\nreporting period of the permanence period is illustrated by a yellow\r\nstar.', alt_text='keep-chart-accu_curve'), 'image15': Image(figure_number='13', figure_number_new=2, figure_caption='Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.', alt_text='keep-chart-precipitation'), 'image16': Image(figure_number='14', figure_number_new=3, figure_caption='Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', alt_text='keep-chart-temperature'), 'image17': Image(figure_number='15', figure_number_new=4, figure_caption='Figure 15. Median number of days with temperatures below 0°C since 1956.', alt_text='keep-chart-frost'), 'image19': Image(figure_number='16', figure_number_new=5, figure_caption='Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', alt_text='keep-chart-drought'), 'image28': Image(figure_number='23', figure_number_new=6, figure_caption='Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', alt_text='keep-image-timeline')}
# Number of <figure> tags before cleaning: 5
# Number of <figure> tags after cleaning: 1
# {'image_id': 'rId10', 'image_file': './media/image2.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-material-symbols-outlined:psychiatry', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'material-symbols-outlined', 'icon': 'psychiatry', 'image_name': 'image2'}
# icon
# {'image_id': 'rId15', 'image_file': './media/image7.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-accu_curve', 'figure_number': 5, 'figure_label': None, 'figure_caption': 'Figure 5. Accumulation curve of gross ACCUs generated each year over the 25-year permanence period. The first recommended reporting period of the permanence period is illustrated by a yellow star.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 1, 'image_type': 'chart', 'chart': 'accu_curve', 'image_name': 'image7', 'figure_caption_new': 'Figure 1. Accumulation curve of gross ACCUs generated each year over the 25-year permanence period. The first recommended reporting period of the permanence period is illustrated by a yellow star.'}
# chart
# {'image_id': 'rId23', 'image_file': './media/image15.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-precipitation', 'figure_number': '13', 'figure_label': None, 'figure_caption': 'Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 2, 'image_type': 'chart', 'chart': 'precipitation', 'image_name': 'image15', 'figure_caption_new': 'Figure 2. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.'}
# chart
# Removing caption paragraph after image 2
# {'image_id': 'rId24', 'image_file': './media/image16.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-temperature', 'figure_number': '14', 'figure_label': None, 'figure_caption': 'Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 3, 'image_type': 'chart', 'chart': 'temperature', 'image_name': 'image16', 'figure_caption_new': 'Figure 3. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.'}
# chart
# Removing caption paragraph after image 3
# {'image_id': 'rId25', 'image_file': './media/image17.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-frost', 'figure_number': '15', 'figure_label': None, 'figure_caption': 'Figure 15. Median number of days with temperatures below 0°C since 1956.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 4, 'image_type': 'chart', 'chart': 'frost', 'image_name': 'image17', 'figure_caption_new': 'Figure 4. Median number of days with temperatures below 0°C since 1956.'}
# chart
# Removing caption paragraph after image 4
# {'image_id': 'rId26', 'image_file': './media/image18.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-custom:drought', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'custom', 'icon': 'drought', 'image_name': 'image18'}
# icon
# {'image_id': 'rId27', 'image_file': './media/image19.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-chart-drought', 'figure_number': '16', 'figure_label': None, 'figure_caption': 'Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 5, 'image_type': 'chart', 'chart': 'drought', 'image_name': 'image19', 'figure_caption_new': 'Figure 5. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.'}
# chart
# Removing caption paragraph after image 6
# {'image_id': 'rId28', 'image_file': './media/image20.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-custom:bushfire', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'custom', 'icon': 'bushfire', 'image_name': 'image20'}
# icon
# Removing caption paragraph after image 7
# {'image_id': 'rId30', 'image_file': './media/image22.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-icon-custom:flood', 'figure_number': None, 'figure_label': None, 'figure_caption': '', 'caption_text': '', 'numbering_type': '', 'figure_number_new': None, 'image_type': 'icon', 'class': 'custom', 'icon': 'flood', 'image_name': 'image22'}
# icon
# {'image_id': 'rId36', 'image_file': './media/image28.png', 'link_id': None, 'link_url': None, 'alt_text': 'keep-image-timeline', 'figure_number': '23', 'figure_label': None, 'figure_caption': 'Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', 'caption_text': '', 'numbering_type': '', 'figure_number_new': 6, 'image_type': 'image', 'alt_text_new': 'timeline', 'image_name': 'image28', 'figure_caption_new': 'Figure 6. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.'}
# image
# Removing caption paragraph after image 9
# Removing orphaned figure caption: Figure 6. Slope across the property.
# Removing orphaned figure caption: Figure 7. Infrastructure that occurs within and around the Pages
# Creek property.
# Removing orphaned figure caption: Figure 8. State-based mapped tenure of the Pages Creek
# property.
# Removing orphaned figure caption: Figure 9. State-based zoning of the Pages Creek
# property.
# Removing orphaned figure caption: Figure 10. Mapping of Indigenous Land Use Agreements in and
# native title determinations in and around the Pages Creek
# property.
# Removing orphaned figure caption: Figure 11. Mining tenements and exploration licenses in and
# around the Pages Creek property.
# Removing orphaned figure caption: Figure 12. Existing Clean Energy Regulator carbon projects in and
# around the Pages Creek property.
# Removing orphaned figure caption: Figure 18. The probability of inundation for the region
# surrounding the Pages Creek property, based on a National Flood Risk
# Model.
# Removing orphaned figure caption: Figure 19.
# Removing orphaned figure caption: Figure 20. Mapped Major Vegetation Groups (MVG) within the Pages
# Creek property
# Removing orphaned figure caption: Figure 21. State-based Pre-European vegetation within the Pages
# Creek property.
# Removing orphaned figure caption: Figure 22. Australian Soil Classification mapping within the
# Pages Creek property.
# Updating in-text reference: '/ha/year, equivalent to approximately
# 807,776 Australian Carbon Credit Units (ACCUs) when considering the risk
# of reversal buffer for a project registered with a permanence period of
# 25 years (Table 4). A breakdown of ACCU generation can be seen in Table
# 5 and Figure 5.' → '/ha/year, equivalent to approximately
# 807,776 Australian Carbon Credit Units (ACCUs) when considering the risk
# of reversal buffer for a project registered with a permanence period of
# 25 years (Table 4). A breakdown of ACCU generation can be seen in Table
# 5 and Figure 1.'
# Updating in-text reference: 'In the summer months, spanning December, January, and February, the
# mean maximum temperature averages around 26.4°C, while the mean minimum
# temperature is approximately 13.4°C. During the winter months of June,
# July, and August, the mean maximum temperature drops to about 13.1°C,
# and the mean minimum temperature averages approximately 2.3°C (Figure
# 14).' → 'In the summer months, spanning December, January, and February, the
# mean maximum temperature averages around 26.4°C, while the mean minimum
# temperature is approximately 13.4°C. During the winter months of June,
# July, and August, the mean maximum temperature drops to about 13.1°C,
# and the mean minimum temperature averages approximately 2.3°C (Figure 3).'
# Updating in-text reference: 'Days below zero degrees Celsius (indexed by frost days) present as a
# risk towards the establishment and survival of young plants. Long term
# data indicates that frost does not occur in and around the property of
# Pages Creek (Figure 15).' → 'Days below zero degrees Celsius (indexed by frost days) present as a
# risk towards the establishment and survival of young plants. Long term
# data indicates that frost does not occur in and around the property of
# Pages Creek (Figure 4).'
# Updating in-text reference: 'Drought risk around the Pages Creek property is ‘high’. In the past
# 20 years, there have been more severe-to-extreme dry periods when
# compared to very-to-extreme wet periods (Figure 16).' → 'Drought risk around the Pages Creek property is ‘high’. In the past
# 20 years, there have been more severe-to-extreme dry periods when
# compared to very-to-extreme wet periods (Figure 5).'
# Updating in-text reference: 'The development of a carbon project follows several key stages
# summarised in Figure 23.' → 'The development of a carbon project follows several key stages
# summarised in Figure 6.'
# Conversion complete! HTML file saved as app/PagesCreekPRO+_FINAL.

# %% [markdown]
# #### END TESTING

# %% [markdown]
# #### FIXING missing figures

# %%
html_images_replaced
# Out:
# '<h2 id="overview">Overview</h2>\n<p>The following is a property-specific assessment of select variables\r\nthat are important to consider when assessing the feasibility of\r\ndeveloping an Environmental Planting (EP).</p>\n<p>You will be able to view fundamental information regarding the\r\npotential opportunity and obstacles to project development.\xa0</p>\n<p>With a PRO and PRO<sup>+</sup> subscription you will also have access\r\nto more elaborate information and interpretation of additional factors\r\nthat are required for critical review in the decision-making process of\r\nyour land assessment and project development.</p>\n<table>\n<caption><p>Table 1. Summary of project details</p></caption>\n<colgroup>\n<col style="width: 40%"/>\n<col style="width: 59%"/>\n</colgroup>\n<thead>\n<tr>\n<th style="text-align: right;">Project Name:</th>\n<th>Pages Creek</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td style="text-align: right;"><strong>Location:</strong></td>\n<td>(Figure 1)</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Project Type:</strong></td>\n<td>Environmental Planting<div class="icon" data-icon-name="psychiatry" data-icon-type="material" data-style="outlined"></div></td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Project Area:</strong></td>\n<td>2,873 ha</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Planting Area:</strong></td>\n<td>1637.76 ha</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Climate\r\nClassification</strong></td>\n<td>Temperate, no dry season (warm summer)</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Local Government Area\r\n(LGA)</strong></td>\n<td>Upper Hunter</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>NRM region</strong></td>\n<td>Hunter Local Land Services</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>IBRA region</strong></td>\n<td>This project is located within the NSW North Coast Interim\r\nBiogeographic Regionalisation for Australia (IBRA) region.</td>\n</tr>\n</tbody>\n</table>\n<h3 id="summary-of-key-risks-affecting-a-carbon-projects-feasibility">Summary\r\nof key risks affecting a carbon projects feasibility</h3>\n<p><em>Table 2. Summary of risk assessment.</em></p>\n<table>\n<colgroup>\n<col style="width: 41%"/>\n<col style="width: 58%"/>\n</colgroup>\n<thead>\n<tr>\n<th>Item assessed</th>\n<th>Assessment</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>Planting Area</td>\n<td><strong>Very low risk.</strong> Less than 5% of the planting area is\r\nclassified as ineligible.</td>\n</tr>\n<tr>\n<td>Carbon Returns</td>\n<td><strong>High returns.</strong> 26.3 ACCUs/ha/year.</td>\n</tr>\n<tr>\n<td>Slope</td>\n<td><strong>Very high risk.</strong> The slope within the planting area\r\nis highly variable and often steep, which is expected to increase\r\noperational complexity and associated costs.</td>\n</tr>\n<tr>\n<td>Other Land Uses</td>\n<td><strong>Very high risk.</strong> There is an existing registered CER\r\nproject located in the property area. There are no mining tenements,\r\nexploration licenses or native title claims intersecting with the\r\nproperty or occurring in the immediate area surrounding the\r\nproperty.</td>\n</tr>\n<tr>\n<td>Infrastructure</td>\n<td><strong>Very low risk.</strong> No major infrastructure intersects\r\nwith the Pages Creek property.</td>\n</tr>\n<tr>\n<td>Tenure</td>\n<td><strong>Very low risk.</strong> The entire property is\r\nFreehold.</td>\n</tr>\n<tr>\n<td>Zoning</td>\n<td><strong>Very low risk.</strong> Property is entirely RU1 and\r\nRU4.</td>\n</tr>\n<tr>\n<td>Climate</td>\n<td><strong>Low risk.</strong> The property is situated in a region\r\nwhere days below zero are frequent in late autumn and early spring.</td>\n</tr>\n<tr>\n<td>Drought Risk</td>\n<td><strong>High risk.</strong> The region is susceptible to increasing\r\ndry periods in recent years.</td>\n</tr>\n<tr>\n<td>Fire Risk</td>\n<td><strong>Moderate risk.</strong> Property hosts a large amount of\r\nfire prone land a ...

# %%
html_more_captions_removed
# Out:
# '<h2 id="overview">Overview</h2>\n<p>The following is a property-specific assessment of select variables\r\nthat are important to consider when assessing the feasibility of\r\ndeveloping an Environmental Planting (EP).</p>\n<p>You will be able to view fundamental information regarding the\r\npotential opportunity and obstacles to project development.\xa0</p>\n<p>With a PRO and PRO<sup>+</sup> subscription you will also have access\r\nto more elaborate information and interpretation of additional factors\r\nthat are required for critical review in the decision-making process of\r\nyour land assessment and project development.</p>\n<table>\n<caption><p>Table 1. Summary of project details</p></caption>\n<colgroup>\n<col style="width: 40%"/>\n<col style="width: 59%"/>\n</colgroup>\n<thead>\n<tr>\n<th style="text-align: right;">Project Name:</th>\n<th>Pages Creek</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td style="text-align: right;"><strong>Location:</strong></td>\n<td>(Figure 1)</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Project Type:</strong></td>\n<td>Environmental Planting<div class="icon" data-icon-name="psychiatry" data-icon-type="material" data-style="outlined"></div></td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Project Area:</strong></td>\n<td>2,873 ha</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Planting Area:</strong></td>\n<td>1637.76 ha</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Climate\r\nClassification</strong></td>\n<td>Temperate, no dry season (warm summer)</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>Local Government Area\r\n(LGA)</strong></td>\n<td>Upper Hunter</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>NRM region</strong></td>\n<td>Hunter Local Land Services</td>\n</tr>\n<tr>\n<td style="text-align: right;"><strong>IBRA region</strong></td>\n<td>This project is located within the NSW North Coast Interim\r\nBiogeographic Regionalisation for Australia (IBRA) region.</td>\n</tr>\n</tbody>\n</table>\n<h3 id="summary-of-key-risks-affecting-a-carbon-projects-feasibility">Summary\r\nof key risks affecting a carbon projects feasibility</h3>\n<p><em>Table 2. Summary of risk assessment.</em></p>\n<table>\n<colgroup>\n<col style="width: 41%"/>\n<col style="width: 58%"/>\n</colgroup>\n<thead>\n<tr>\n<th>Item assessed</th>\n<th>Assessment</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>Planting Area</td>\n<td><strong>Very low risk.</strong> Less than 5% of the planting area is\r\nclassified as ineligible.</td>\n</tr>\n<tr>\n<td>Carbon Returns</td>\n<td><strong>High returns.</strong> 26.3 ACCUs/ha/year.</td>\n</tr>\n<tr>\n<td>Slope</td>\n<td><strong>Very high risk.</strong> The slope within the planting area\r\nis highly variable and often steep, which is expected to increase\r\noperational complexity and associated costs.</td>\n</tr>\n<tr>\n<td>Other Land Uses</td>\n<td><strong>Very high risk.</strong> There is an existing registered CER\r\nproject located in the property area. There are no mining tenements,\r\nexploration licenses or native title claims intersecting with the\r\nproperty or occurring in the immediate area surrounding the\r\nproperty.</td>\n</tr>\n<tr>\n<td>Infrastructure</td>\n<td><strong>Very low risk.</strong> No major infrastructure intersects\r\nwith the Pages Creek property.</td>\n</tr>\n<tr>\n<td>Tenure</td>\n<td><strong>Very low risk.</strong> The entire property is\r\nFreehold.</td>\n</tr>\n<tr>\n<td>Zoning</td>\n<td><strong>Very low risk.</strong> Property is entirely RU1 and\r\nRU4.</td>\n</tr>\n<tr>\n<td>Climate</td>\n<td><strong>Low risk.</strong> The property is situated in a region\r\nwhere days below zero are frequent in late autumn and early spring.</td>\n</tr>\n<tr>\n<td>Drought Risk</td>\n<td><strong>High risk.</strong> The region is susceptible to increasing\r\ndry periods in recent years.</td>\n</tr>\n<tr>\n<td>Fire Risk</td>\n<td><strong>Moderate risk.</strong> Property hosts a large amount of\r\nfire prone land a ...

# %%
figure_captions = dc.get_figure_captions(initial_html_clean, doc_img_src)
figure_captions
# Out:
# {'image7': Image(figure_number=5, figure_number_new=1, figure_caption='Figure 5. Accumulation curve of gross ACCUs generated\r\neach year over the 25-year permanence period. The first recommended\r\nreporting period of the permanence period is illustrated by a yellow\r\nstar.', alt_text='keep-chart-accu_curve')}

# %%
print(f"Figure captions: {figure_captions}")
keep_image_map_types = [
    {**item, 'image_name': os.path.splitext(os.path.basename(item.get('image_file', '')))[0]}
    for item in keep_image_map_types
]

keep_image_map_types_figure_captions = [
    {
        **item,
        **(
            {
                'figure_caption': dc.clean_figure_caption(fc.figure_caption),
                'figure_number': fc.figure_number,
                'figure_number_new': fc.figure_number_new,
                'figure_caption_new': re.sub(
                    str(fc.figure_number),
                    str(fc.figure_number_new),
                    dc.clean_figure_caption(fc.figure_caption),
                    count=1
                )
            } if (fc := figure_captions.get(item["image_name"])) else {}
        )
    }
    for item in keep_image_map_types
]
# Out:
# <div data-navigation=""></div>
# <h1 id="overview">Overview</h1>
# <p>The following is a property-specific assessment of select variables
#
# that are important to consider when assessing the feasibility of
#
# developing an Environmental Planting (EP).</p>
# <p>You will be able to view fundamental information regarding the
#
# potential opportunity and obstacles to project development. </p>
# <p>With a PRO and PRO<sup>+</sup> subscription you will also have access
#
# to more elaborate information and interpretation of additional factors
#
# that are required for critical review in the decision-making process of
#
# your land assessment and project development.</p>
# <div data-parent="overview" data-sub-navigation=""></div>
# <h2 id="summary-of-assessment">Summary of Assessment</h2>
# <div class="table" id="table_0"></div><br/>
# <h3 id="summary-of-key-risks-affecting-a-carbon-projects-feasibility">Summary
#
# of Key Risks Affecting a Carbon Projects Feasibility</h3>
# <div class="table" data-caption="&lt;p&gt;Table 1. Summary of assessment.&lt;/p&gt;" id="table_1"></div><br/>
# <h1 id="carbon">Carbon</h1>
# <p>This section provides information that allows you to evaluate the
#
# carbon potential of your project area, assess eligibility with the
#
# Environmental Planting method and generate valuable insights for
#
# optimising project returns.</p>
# <div data-parent="carbon" data-sub-navigation=""></div>
# <h2 id="planting-area">Planting Area</h2>
# <p>The Clean Energy Regulator (CER) sets specific eligibility
#
# requirements for what qualifies as a planting area in environmental
#
# planting projects under the Emissions Reduction Fund (ERF). These
#
# requirements are intended to minimise the risk of perverse environmental
#
# outcomes driven solely by carbon credit generation, while ensuring
#
# projects deliver a net increase in carbon sequestration.</p>
# <p>Using the National Forest and Sparse Woody dataset, a two-stage
#
# process is used to estimate the planting area:</p>
# <ol type="1">
# <li><p>Assessment and removal of areas where land clearing has occurred
#
# within the project area in the last 7 years<a class="footnote-ref" href="#fn1" id="fnref1" role="doc-noteref"><sup>1</sup></a>. </p></li>
# <li><p>Calculating the planting area as the total remaining area that is
#
# classified as ‘non-woody’ and that is not an identified exclusion
#
# area.</p></li>
# </ol>
# <p>Represented on the map, approximately 255.0 hectares of the total
#
# property area, are classified as eligible for the establishment of an EP
#
# carbon project. Areas suspected of clearing constitute 0.53 hectares of
#
# the total property area. </p>
# <div class="table" data-caption="&lt;p&gt;Table 2. Detailed breakdown of estimation of the eligible
#
# planting area estimated by grovia using the National Forest and Sparse
#
# Woody Vegetation Data, 2023.&lt;/p&gt;" id="table_2"></div><br/>
# <h2 id="carbon-assessment">Carbon Assessment</h2>
# <p>Carbon assessment is a critical in evaluating the potential of a
#
# carbon project, as it quantifies how much carbon can be sequestered or
#
# avoided over time. This directly informs the project's carbon yield,
#
# defined as the amount of carbon dioxide equivalent (tCO₂-e) captured per
#
# hectare annually. Understanding carbon yield helps determine the
#
# environmental impact and economic viability of the project, guiding
#
# decisions on land use, management practices, and long-term returns.</p>
# <p>A carbon heatmap (see corresponding map overlay) visually represents
#
# the distribution and capacity of the land to store aboveground carbon.
#
# This allows you to review and optimise your planting area based on the
#
# potential carbon yield.</p>
# <p>The most productive areas for planting are located [at the
#
# northwestern end] of the property, with the remaining high carbon yield
#
# areas located [in the woody forest portion of the lot].</p>
# <p>An initial method-compliant FullCAM carbon assessment stratified the
#
# property into five carbon estimation areas (CEAs). CEAs were defined by
#
# land homogeneity, ensuring that land within a CEA exhibited similar
#
# characteristics that can be defined using desktop resources such as soil
#
# type and slope (see CEA stratification Table below). It is highly
#
# recommended that a site visit is conducted to assess other factors such
#
# as land management history.</p>
# <p>The initial desktop FullCAM carbon assessment indicated a potential
#
# return of 7.6 tCO<sub>2</sub>/ha/year, equivalent to approximately
#
# 255,876 Australian Carbon Credit Units (ACCUs) when considering the risk
#
# of reversal buffer for a project registered with a permanence period of
#
# 25 years.</p>
# <div class="table" data-caption="&lt;p&gt;Table 3. CEA stratification&lt;/p&gt;" id="table_3"></div><br/>
# <div class="table" data-caption="&lt;p&gt;Table 4. Detailed breakdown of estimated Carbon Yield from
#
# an initial FullCAM carbon assessment.&lt;/p&gt;" id="table_4"></div><br/>
# <p><strong>Key Action</strong>: A site visit is required to refine the
#
# planting area and determine other factors that may result in further CEA
#
# stratification before re-running a method compliant FullCAM
#
# assessment.</p>
# <h3 id="carbon-credits">Carbon Credits</h3>
# <p>This section provides insight into the total credit issuance
#
# trajectory of gross Australian Carbon Credit Units (ACCUs) over a
#
# 25-year permanence period.</p>
# <div class="table" data-caption="&lt;p&gt;Table 5. The cumulative generation of gross ACCUs each year
#
# over the 25-year permanence period.&lt;/p&gt;" id="table_5"></div><br/>
# <h1 id="site-information">Site Information</h1>
# <p>To determine whether a project area is suitable for a carbon
#
# sequestration project (such as environmental plantings under the
#
# Emissions Reduction Fund (ERF)), several factors must be assessed,
#
# including topography, infrastructure and land titles. </p>
# <div data-parent="site-information" data-sub-navigation=""></div>
# <h2 id="slope">Slope</h2>
# <p>Slope is an important consideration for assessing EP carbon projects
#
# as it can directly influence future planting operations such as the
#
# operation of heavy machinery or by limiting accessibility. This section
#
# and the corresponding map overlay ‘Slope’ provide an overview of the
#
# topography of the specified project area.</p>
# <p>The topography of the property can be described as a predominantly
#
# flat landscape with larger angle slopes occurring in forested areas.
#
# From a desktop assessment, the property poses as moderate risk for the
#
# impact of slope on operations, especially site preparation. When
#
# assessing the slope of the planting area, almost 90% of the planting
#
# area is within a 0–11 degrees slope range and the remaining 9.97%
#
# between 11-22 degrees.</p>
# <div class="table" data-caption="&lt;p&gt;Table 6. Planting area defined by slope.&lt;/p&gt;" id="table_6"></div><br/>
# <h2 id="infrastructure">Infrastructure</h2>
# <p>Effective planning of carbon sequestration projects requires a
#
# thorough assessment of how existing infrastructure affects land
#
# suitability and project boundaries. Features such as buildings, sheds,
#
# water storage, and roads must be clearly identified to establish
#
# appropriate buffer zones and ensure that project development does not
#
# compromise the functionality or accessibility of these assets.</p>
# <p>This also extends to major infrastructure such as transmission lines,
#
# as they can present several risks to a carbon sequestration project,
#
# particularly environmental planting projects under the Emissions
#
# Reduction Fund (ERF). These risks can affect project eligibility, carbon
#
# credit generation, and long-term permanence obligations. For example, if
#
# transmission line operators require land clearing for maintenance or
#
# upgrades, this could violate the permanence requirement, jeopardizing
#
# ACCUs already issued. </p>
# <h2 id="tenure">Tenure</h2>
# <p>Tenure is critical for carbon projects as it establishes legal
#
# ownership and land-use rights for the project site. Understanding the
#
# tenure type(s) of your project area is essential for determining project
#
# legitimacy, securing necessary permissions, and identifying key
#
# stakeholders involved in project development. Clear tenure ensures
#
# long-term stability and compliance, reducing risks to project
#
# success.</p>
# <p>To confirm the tenure of the property under discussion, legal
#
# expertise is required. However, Initial assessment indicates that the
#
# property is almost entirely Freehold tenure.</p>
# <p>Other tenure classifications include Freehold - Indigenous land and
#
# Freehold leasing and where on the property, which make up 10% of the
#
# total land. Refer to the corresponding map overlay ‘Tenure’ to
#
# understand which areas are classified by which tenure type.</p>
# <p>This area of the property may be subject to certain restrictions to
#
# protect the cultural and heritage significance of the land for the local
#
# indigenous community. However, the size of this tenure is both marginal
#
# and may be an artefact of ‘clipping’ the data layer by the property
#
# boundary. Furthermore, the areas identified as ‘Freehold – Indigenous’
#
# and ‘Freehold leasing’ are located within woody forests that can be
#
# omitted from the project area.</p>
# <p>grovia recommends that as a part of the project due diligence
#
# process, consultation and engagement with the local indigenous group is
#
# required prior to initiating any changes in land use and development, as
#
# well as to determine if any significant cultural sites are present
#
# within that area.</p>
# <h2 id="zoning">Zoning</h2>
# <p>Zoning dictates how land can be used, ensuring that projects align
#
# with legal and regulatory frameworks. If zoning laws don’t support
#
# conservation or reforestation, a project might fail verification and not
#
# generate credits.</p>
# <p>State-based zoning indicates that the property is zoned as primary
#
# production RU1 and presents high risk for project development.</p>
# <h2 id="land-titles">Land Titles</h2>
# <p>It is essential to evaluate whether a proposed project area is
#
# subject to land titles or other land uses that could potentially
#
# conflict with the development of a carbon project. While these
#
# alternative uses may not always prevent project implementation, they
#
# serve as indicators of potential risk, can influence the project
#
# timeline, and help identify key stakeholders who may need to be
#
# consulted during the planning process.</p>
# <h3 id="native-title">Native Title</h3>
# <p>Native title is a crucial assessment criterion for carbon projects as
#
# it identifies land tenure rights, Indigenous stakeholder engagement, and
#
# consent requirements, ensuring projects comply with legal frameworks and
#
# respect Traditional Owner interests.</p>
# <p>There is history of native title claims or native title
#
# determinations in or in the immediate area around the property.</p>
# <h3 id="mining-tenements-and-exploration-licences">Mining Tenements and
#
# Exploration Licences</h3>
# <p>Understanding mining tenements and exploration licenses help ensure
#
# project security, regulatory compliance and alignment with long-term
#
# land management objectives.</p>
# <p>There are currently no mining leases or exploration licenses
#
# occurring within the property boundary.</p>
# <h3 id="existing-cer-projects">Existing CER Projects</h3>
# <p>If an area is already covered by an existing CER project, there is a
#
# risk of double counting carbon credits which can lead to non-compliance
#
# with carbon standards and making credits invalid or reducing their
#
# market value. Similarly, if an existing CER project is already
#
# addressing the same emission reductions, the new project might fail
#
# additionality tests and be ineligible for credits.</p>
# <p>At present, there are no registered CER projects within the property.
#
# There are existing projects that occur in the region surrounding the
#
# property.</p>
# <h1 id="environmental">Environmental</h1>
# <p>Carbon projects, particularly those involving environmental
#
# plantings, face various environmental risks that can affect their
#
# success, long-term viability, and ability to generate Australian Carbon
#
# Credit Units (ACCUs). These risks must be carefully assessed and managed
#
# to ensure project permanence and compliance with Emissions Reduction
#
# Fund (ERF) requirements.</p>
# <div data-parent="environmental" data-sub-navigation=""></div>
# <h2 id="climate">Climate</h2>
# <p>Climate and weather-related risks (e.g. rainfall and temperature),
#
# play a significant role in determining the success and long-term
#
# viability of carbon projects, particularly those focused on
#
# environmental plantings. These risks can affect carbon sequestration
#
# rates, project costs, and the ability to meet permanence obligations (25
#
# or 100 years) under the Emissions Reduction Fund (ERF).</p>
# <h3 id="precipitation">Precipitation</h3>
# <p>Adequate rainfall is crucial for the growth and survival of
#
# vegetation used in carbon projects, especially in reforestation and
#
# revegetation efforts.</p>
# <p>The region surrounding the property receives a long-term annual
#
# average of 10 mm. Annual rainfall trends show that mean monthly rainfall
#
# is consistent throughout the year, with the highest between November and
#
# March averaging between 44 - 63 mm per month compared to 20 - 34 mm in
#
# April to September.</p>
# <figure>
# <div class="chart" data-caption="Figure 1. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024." id="precipitation"></div>
# <figcaption><p>Figure 4. Interpolated climate data from the Bureau of
#
# Meteorology and other providers at a 5km resolution. Average monthly
#
# precipitation (mm) over the year of the area surrounding the property
#
# using data from 1956 – 2024.</p></figcaption>
# </figure>
# <h3 id="temperature">Temperature</h3>
# <p>Temperature impacts suitable planting windows and directly affects
#
# the rate of photosynthesis in plants. Higher temperatures can increase
#
# the growth rates of vegetation, leading to faster carbon
#
# sequestration.</p>
# <p>In this region, mean monthly maximum temperatures range from 12 °C in
#
# summer to 10 °C in winter and mean monthly minimum temperatures range
#
# from 25 °C in summer to 0 °C in winter (Figure 5).</p>
# <p>In the past ten years, recent temperature trends show that
#
# temperatures in January are significantly warmer when compared to
#
# historical data (1956-2024) (Figure 5).</p>
# <figure>
# <div class="chart" data-caption="Figure 2. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024." id="temperature"></div>
# <figcaption><p>Figure 5. Interpolated climate data from the Bureau of
#
# Meteorology and other providers at a 5km resolution. The figure shows
#
# the mean minimum and mean maximum monthly temperatures from data between
#
# 1956 to 2024.</p></figcaption>
# </figure>
# <h3 id="frost">Frost</h3>
# <p>Frost tolerant plants may be required in your region.</p>
# <p>Between May and September, 10 days below 0°C are to be expected each
#
# month, with average days below 0°C per month ranging between 10 – 23
#
# (Figure 6).</p>
# <figure>
# <div class="chart" data-caption="Figure 3. Median number of days with temperatures below 0°C since 1956." id="frost"></div>
# <figcaption><p>Figure 6. Median number of days with temperatures below
#
# 0°C since 1956.</p></figcaption>
# </figure>
# <h2 id="drought-risk">Drought Risk</h2>
# <p>Drought and reduced rainfall can significantly impact on carbon
#
# projects. For example, by degrading soil, increasing mortality of
#
# seedlings, slowing down tree growth - in turn all impacting
#
# sequestration rates, requiring replanting and increasing costs.<div class="icon" data-caption="{{droughtRisk}}" data-icon-name="drought" data-icon-type="custom"></div></p>
# <p>Assessment of water access is highly recommended during a site
#
# visit.</p>
# <figure>
# <div class="chart" data-caption="Figure 4. SPEI-6 shows anomalies in the comparison of precipitation and evapotranspiration over a moving 6 month window using interpolated BoM data from between 1956 to 2024." id="drought"></div>
# <figcaption><p>Figure 7. SPEI-6 shows anomalies in the comparison of
#
# precipitation and evapotranspiration over a moving 6 month window using
#
# interpolated BoM data from between 1956 to 2024.</p></figcaption>
# </figure>
# <h2 id="bushfire-risk">Bushfire Risk</h2>
# <p>Increased fire risk threatens above-ground carbon storage. <div class="icon" data-caption="{{bushfireRisk}}" data-icon-name="bushfire" data-icon-type="custom"></div></p>
# <p>The ‘historic bushfire’ overlay on the right shows bushfires that
#
# have occurred in the area 50km radius of the property since 1906.</p>
# <p>Fire is common in this region and occur predominantly to the west of
#
# the property. These can be identified in the associated map overlay. The
#
# closest of these fires include 2010. More recent fires in the immediate
#
# area have occurred in the same timbered area, but as prescribed,
#
# controlled burns. The area was not subject to the Black Summer Fires of
#
# 2019-2020. The properties propensity for bushfire is under a Vegetation
#
# Category 1 or moderate bushfire risk.</p>
# <h2 id="flood-risk">Flood Risk</h2>
# <p>Flooding &amp; Heavy Rainfall Events impacts on carbon projects
#
# through causing erosion &amp; soil loss, damage to seedlings and plant
#
# roots, which may kill plants and slow sequestration, increasing
#
# replanting costs.<div class="icon" data-caption="{{floodRisk}}" data-icon-name="flood" data-icon-type="custom"></div></p>
# <p>The ‘flood hazard’ overlay on the map visualises areas of the
#
# property that are at risk of flooding.</p>
# <p>As part of the initial desktop assessment, grovia has reviewed the
#
# risk of flood from two sources:</p>
# <ol type="1">
# <li><p>A National Flood Risk Model (FRM) based on a
#
# statistical-morphological approach which determines inundation
#
# probability.</p></li>
# <li><p>Risk of future floods weighted by the ability to respond to a
#
# flooding event.</p></li>
# </ol>
# <p>The National FRM deems the risk of flood in the LGA is low, with the
#
# property presenting as negligible. However, an assessment that weighs
#
# the risk of flooding and the subsequent knock-on effects with a region’s
#
# potential to lose economic activity due to natural perils indicates that
#
# flooding risk is very high (see associated map overlay). It is likely
#
# that this secondary assessment reflects the regions geographic isolation
#
# and the socio-economic capacity to recover from a natural disaster such
#
# as flood.</p>
# <p>Overall, grovia’s desktop assessment of how flood may impact project
#
# success on the property is moderate. grovia recommends that a site visit
#
# is conducted to assess evidence of past floods and high rainfall events
#
# such as soil erosion or land slips.</p>
# <h2 id="salinity">Salinity</h2>
# <p>Salinity, or the concentration of salt in soil and water, can
#
# significantly influence the success and carbon sequestration potential
#
# of environmental projects, where high salinity can be a major constraint
#
# on plant growth and soil health, making it a critical factor to consider
#
# in carbon project design and management.</p>
# <h3 id="dryland-salinity">Dryland Salinity</h3>
# <p>Dryland salinity refers to the accumulation of salts in the soil of
#
# non-coastal (dryland) areas, which primarily affects agricultural lands,
#
# natural ecosystems, and water quality. It occurs in areas with low
#
# rainfall and can result from both natural processes and human
#
# activities, often exacerbated by land use changes such as agriculture
#
# and deforestation.</p>
# <p>The ‘dryland salinity’ overlay on the map shows whether there is a
#
# risk of having high salinity. </p>
# <p>There is no risk of dryland salinity for the property, with the
#
# closest dryland salinity risk area located approximately 40km from the
#
# property (see associated map overlay).</p>
# <h3 id="surface-salinity">Surface Salinity</h3>
# <p>Surface salinity is when salts accumulate on or near the soil
#
# surface, often visible as white crusts, due to rising water tables or
#
# poor. Currently, mapping of surface salinity is not available
#
# nationally.</p>
# <p>Data not available for this location</p>
# <h1 id="biogeography">Biogeography</h1>
# <p>In the context of carbon projects, biogeography plays a crucial role
#
# in determining suitable locations, vegetation types, and carbon
#
# sequestration potential for environmental plantings.</p>
# <div data-parent="biogeography" data-sub-navigation=""></div>
# <h2 id="vegetation">Vegetation</h2>
# <h3 id="national-pre-european-vegetation">National pre-European
#
# Vegetation</h3>
# <p>Australia's vegetation is classified into Major Vegetation Groups
#
# (MVGs) at a national scale based on dominant plant communities, climate,
#
# and ecological characteristics (pre-European settlement). These
#
# classifications help in determining the potential yield for carbon
#
# sequestration projects. For instance, Forests &amp; Woodlands (Eucalypt,
#
# Acacia, Casuarina) have high carbon sequestration potential, whereas
#
# Grasslands &amp; Shrublands (Spinifex, Saltbush) are often less viable
#
# for ACCU projects unless revegetation is planned.</p>
# <p>The map overlay ‘Major Vegetation Groups’ highlights the vegetation
#
# classification for the property. </p>
# <p>At a national scale of vegetation classification, most of the
#
# eligible planting area is categorised as Tussock Grasslands which are
#
# characterised by open grasslands with few trees interspersed across the
#
# landscape and Eucalyptus Open Forest. This may prove as a risk to
#
# provide forest cover, as this ecosystem is naturally characterised by
#
# very low tree density.</p>
# <p><em>Figure 6. Major Vegetation Groups (MVG)</em></p>
# <h3 id="state-level-pre-european-vegetation">State Level pre-European
#
# Vegetation</h3>
# <p>Pre-European vegetation (PEV) mapping offers valuable insights into
#
# the natural ecosystems that existed before significant human
#
# intervention. PEVs help define an initial benchmark for restoration
#
# goals, guide species selection, optimising planting strategies, and also
#
# inform potential project co-benefits such as restoring threatened
#
# ecological communities and/or critical habitat for threatened species.
#
# By restoring PEVs, projects increase their likelihood of qualifying for
#
# higher quality carbon credits while simultaneously delivering local
#
# benefits to native flora and fauna, thereby improving landscape-scale
#
# system resilience.  </p>
# <p>In accordance with ‘Pre-European Vegetation’ mapping, there are 6
#
# PEVs on the property (called Plant Community Types (PCTs) for this
#
# state).</p>
# <p>The dominant PCTs that cover the eligible planting areas are Monaro
#
# Kangaroo Grass Woodland-Grassland Complex and Monaro-Gourock Frost
#
# Hollow Grassy Woodland. In accordance to PCT mapping, 100% of Kalimna
#
# can achieve forest cover. grovia recommends that a site visit is
#
# conducted to establish reference sites that reflect the PCT communities,
#
# found within the property, in neighbouring remnant vegetation and to
#
# evaluate the properties capacity for revegetation.</p>
# <h2 id="soil">Soil</h2>
# <p>Soil is fundamental to the success of any restoration project,
#
# directly impacting plant establishment and long-term survival.
#
# Understanding soil characteristics helps identify risks early and
#
# informs key actions such as targeted soil testing, land remediation, and
#
# site preparation. A well-informed soil assessment ensures a strong
#
# foundation for restoration success.</p>
# <p>The soils on the property are mainly chromosol and some tenosol
#
# soils. The map overlay ‘Soil’ highlights the soil properties for the
#
# property. </p>
# <p>In accordance with the Australian Soils Classification mapping, the
#
# property soils are comprised of predominantly chromosol in the eligible
#
# planting areas and tenosol in the areas with remnant woody
#
# vegetation.</p>
# <p>Based on the soil properties and assumed land management practices,
#
# the property presents a low risk for project development.</p>
# <p>A site visit is recommended to generate a more accurate understanding
#
# of soil makeup and whether past land use (e.g. the use of fertilisers)
#
# may influence future planting operations.</p>
# <h2 id="potential-weeds">Potential Weeds</h2>
# <p>Weeds present a major threat to both the farming industry and
#
# Australia’s natural environment, with problematic species varying by
#
# region. Identifying key weeds in your project area enables targeted
#
# ecological assessments, helps gauge their potential impact on project
#
# success, and informs cost-effective management strategies. Early
#
# detection and proactive control are essential to ensuring a compliant,
#
# resilient, and high-quality carbon project.</p>
# <p>grovia has conducted a preliminary assessment of the significant
#
# ‘problem weeds’ that occur in the region of the property. These species
#
# have been identified based on their characteristics that deem them as
#
# weeds of national significance (WONS), or weeds that have been
#
# recognised as problematic in the local area.</p>
# <p>There are at least 26 weed species that can potentially occur within
#
# the property or are known to be present in the area; of the 26, 17 are
#
# weeds of national security. Further investigation and ground truthing
#
# will determine what weed species are present on and surrounding the
#
# property.</p>
# <div class="table" data-caption="&lt;p&gt;Table 7. List of notable weeds in the region surrounding the
#
# property (not exhaustive).&lt;/p&gt;" id="table_7"></div><br/>
# <h1 id="next-steps">Next steps</h1>
# <div data-parent="next-steps" data-sub-navigation=""></div>
# <h2 id="summary">Summary</h2>
# <p>Overall, the Armidale property presents as a low yielding carbon EP
#
# project with some key risks that may threaten the project viability over
#
# time. Based on this comprehensive, property-specific assessment of
#
# factors relevant to the feasibility of an Environmental Planting (EP)
#
# carbon project on your land, it is highly recommended that a site visit
#
# is conducted to ground truth these initial desktop observations.</p>
# <h3 id="the-carbon-project-journey-from-assessment-to-management">The
#
# Carbon Project Journey: From Assessment to Management</h3>
# <p>The development of a carbon project follows several key stages
#
# summarised in Figure 8.</p>
# <p>This desktop assessment is part of the ‘Due Diligence’ stage; a
#
# thorough and structured process of assessing a project before making a
#
# commitment to proceed. grovia supports this critical stage with
#
# additional tools such as Cost Calculator to understand your net position
#
# after costs and preparing for a site visit. Together, these features
#
# provide a strong foundation for confident, informed decision-making.</p>
# <h2 id="considerations">Considerations</h2>
# <p>Evaluating the feasibility of an EP project requires the further
#
# analysis of factors that may influence project development.</p>
# <ul>
# <li><p>To assess whether the modelled vegetation communities present as
#
# a risk factor for an EP project to establish 20% forest cover</p></li>
# <li><p>To assess the pest management regime of neighbouring remnant
#
# woody areas and to inspect the condition of boundary fences.</p></li>
# <li><p>To strategise and refine the species list for restoration based
#
# on limiting factors such as seed availability.</p></li>
# </ul>
# <p>Project proponents<a class="footnote-ref" href="#fn2" id="fnref2" role="doc-noteref"><sup>2</sup></a> are also required to assess
#
# additional risks such as whether there is a legal right to develop a
#
# project by considering variables such as land tenure, zoning, native
#
# title claims and how regional and local strategic plans may impede
#
# project establishment.</p>
# <h2 id="action-plan">Action Plan</h2>
# <h3 id="what-else-is-involved-with-an-ep-project">What Else is Involved
#
# with an EP Project? </h3>
# <p>If your property shows promise for an EP carbon project, you have
#
# three ways to move forward:</p>
# <h3 id="understand-whats-involved-to-be-registration-ready">1.
#
# Understand What’s Involved to Be Registration Ready</h3>
# <p>Familiarise yourself with the key requirements and milestones needed
#
# to progress toward registration with the Clean Energy Regulator (CER).
#
# This includes preparing documentation such as a Reforestation Management
#
# Plan and Permanence Plan to support your application. Clarity at this
#
# stage sets a strong foundation for everything that follows.</p>
# <p>→ Best for those wanting a clear understanding of what’s required to
#
# get registration-ready before taking the next step.</p>
# <h3 id="prepare-for-your-site-visit">2. Prepare for Your Site Visit</h3>
# <p>Get ready for the critical site visit that validates your desktop
#
# assessment and moves your project from concept to ground-truthed
#
# reality. This step includes verifying mapped exclusion zones (e.g.
#
# deforested areas), identifying on-site constraints, and completing
#
# vegetation community (PCT) mapping to inform your species list.</p>
# <p>Information gathered during the site visit will likely inform the
#
# recalculation of potential ACCUs by refining planting and exclusion
#
# areas; helping you better estimate the project’s carbon yield. A
#
# well-prepared visit enables accurate data capture and sets the stage for
#
# confident planning decisions.</p>
# <p>→ Best for those ready to ground-truth their project and start
#
# getting practical about planting and implementation.</p>
# <h3 id="plan-your-planting">3. Plan Your Planting</h3>
# <p>Refine your restoration strategy by designing a site-specific
#
# planting plan. This includes determining line layout and spacing,
#
# selecting appropriate species, and choosing the most suitable planting
#
# method. Use the <em>Seeds Near Me</em> module to develop a species list
#
# tailored to local conditions and informed by seed availability. This
#
# step is essential for ensuring ecological integrity and meeting Clean
#
# Energy Regulator (CER) compliance requirements.</p>
# <p>→ Best for those looking to prepare an optimal planting plan and move
#
# confidently toward implementation.</p>
# <h3 id="lets-talk">Let’s Talk</h3>
# <p>Our team is available to support you with your next steps, whether
#
# that involves refining your proposed planting area after a site visit or
#
# moving forward with project registration.</p>
# <p>We're here to help; reach out anytime and we'll work with you to find
#
# the best path forward.</p>
# <p>contact@grovia.earth</p>
# <section class="footnotes footnotes-end-of-document" id="footnotes" role="doc-endnotes">
# <hr/>
# <ol>
# <li id="fn1"><p> Areas designated for planting under the Reforestation
#
# by Environmental or Mallee planting method must not have had forest
#
# cover within the past 5 years. Furthermore, all CER carbon projects that
#
# involve establishing vegetation on land require that there must not have
#
# been clearing of any native forest within the 7 years of lodging the
#
# application (5 years if the land has changed ownership since the
#
# clearing). grovia’s initial assessment flags the likelihood that a
#
# property may encounter issues with eligibility if the project was to
#
# progress. grovia recommends that a site visit and further investigation
#
# is required to ground-truth these results.<a class="footnote-back" href="#fnref1" role="doc-backlink">↩︎</a></p></li>
# <li id="fn2"><p>A project proponent is the party who has the legal right
#
# to develop a project and is responsible for carrying out the project, is
#
# issued credits for the project and is legally responsible for meeting
#
# all obligations under the law. See <a href="https://cer.gov.au/schemes/australian-carbon-credit-unit-scheme/how-to-participate/plan-your-project/choose-project-proponent"><u>https://cer.gov.au/schemes/australian-carbon-credit-unit-scheme/how-to-participate/plan-your-project/choose-project-proponent</u></a>
#
# for more information.<a class="footnote-back" href="#fnref2" role="doc-backlink">↩︎</a></p></li>
# </ol>
# </section>

# %% [markdown]
# #### END FIXING missing figures

# %%
from zipfile import ZipFile
import xml.etree.ElementTree as ET

html_content = initial_html_clean

# Namespaces used in Word XML
ns = {
    'w': 'http://schemas.openxmlformats.org/wordprocessingml/2006/main',
    'a': 'http://schemas.openxmlformats.org/drawingml/2006/main',
    'r': 'http://schemas.openxmlformats.org/officeDocument/2006/relationships',
    'wp': 'http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing'
}

figures = []

with ZipFile(docx_path) as docx:
    # Step 1: Extract only the document.xml
    with docx.open('word/document.xml') as file:
        tree = ET.parse(file)
        root = tree.getroot()

    # Step 2: Extract image and caption info
    paragraphs = root.findall('.//w:p', ns)

    for i, p in enumerate(paragraphs):
        img_tag = p.find('.//a:blip', ns)
        if img_tag is not None:
            r_id = img_tag.attrib.get(f'{{{ns["r"]}}}embed')
            # Look ahead for the caption (next paragraph)
            caption_text = ''
            if i + 1 < len(paragraphs):
                next_p = paragraphs[i + 1]
                caption_text = ''.join([t.text or '' for t in next_p.findall('.//w:t', ns)])
            figures.append({'rId': r_id, 'caption': caption_text})

# Step 3: Verify which figures have captions starting with "Figure {d} or Figure {letters}"
figures_verified = []
for fig in figures:
    caption = fig['caption']
    if caption.startswith("Figure"):
        match = re.search(r"Figure [A-Za-z0-9]+", caption)
        if match:
            figure_number = match.group(0)
            caption_after = caption.split(figure_number)[1].strip()
            figures_verified.append({'rId': fig['rId'], 'caption': caption, 'html_caption': caption_after})

# Step 4: Check for missing figures in the html
missing_figures = {}
soup = BeautifulSoup(html_content, 'html.parser')
figure_tags = soup.find_all('figcaption')

# Identify missing captions that are in the docx but not in the html
for fig in figures_verified:
    found = False
    for fig_tag in figure_tags:
        if fig['html_caption'] in fig_tag.text.replace("\r\n", " "):
            found = True
            break
    if not found:
        missing_figures[fig['rId']] = fig['caption'].rstrip() # Remove trailing whitespace

# %%
img_tag.attrib
# Out:
# {'{http://schemas.openxmlformats.org/officeDocument/2006/relationships}embed': 'rId37'}

# %%
import xml.etree.ElementTree as ET
from zipfile import ZipFile
import base64

ns = {
    'w': 'http://schemas.openxmlformats.org/wordprocessingml/2006/main',
    'a': 'http://schemas.openxmlformats.org/drawingml/2006/main',
    'r': 'http://schemas.openxmlformats.org/officeDocument/2006/relationships',
    'wp': 'http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing'
}

figures = []

with ZipFile(docx_path) as docx:
    # Load main document
    with docx.open('word/document.xml') as file:
        tree = ET.parse(file)
        root = tree.getroot()

    # Load image relationships
    rels = {}
    with docx.open('word/_rels/document.xml.rels') as rels_file:
        rels_tree = ET.parse(rels_file)
        for rel in rels_tree.findall('Relationship', {'': 'http://schemas.openxmlformats.org/package/2006/relationships'}):
            r_id = rel.attrib['Id']
            target = rel.attrib['Target']
            if target.startswith('media/'):
                rels[r_id] = f'word/{target}'

    # Search all <wp:inline> and <wp:anchor> blocks (image containers)
    image_blocks = root.findall('.//wp:inline', ns) + root.findall('.//wp:anchor', ns)

    for block in image_blocks:
        blip = block.find('.//a:blip', ns)
        docPr = block.find('wp:docPr', ns)

        if blip is not None:
            r_id = blip.attrib.get(f'{{{ns["r"]}}}embed')
            alt_text = ''
            if docPr is not None:
                alt_text = docPr.attrib.get('descr', '') or docPr.attrib.get('title', '')

            # Find image path and base64 encode it
            img_path = rels.get(r_id)
            img_data = None
            if img_path:
                with docx.open(img_path) as img_file:
                    img_bytes = img_file.read()
                    img_data = base64.b64encode(img_bytes).decode('utf-8')

            # Attempt to find the *next* paragraph after this block for caption
            # by checking position in the full list of elements
            caption_text = ''
            parent = block.getparent() if hasattr(block, 'getparent') else None  # not supported in ElementTree
            # Instead, just find all paragraphs and match by rId position
            paragraphs = root.findall('.//w:p', ns)
            next_caption_found = False
            for i, p in enumerate(paragraphs):
                if p.find('.//a:blip[@r:embed="%s"]' % r_id, ns) is not None:
                    if i + 1 < len(paragraphs):
                        next_p = paragraphs[i + 1]
                        caption_text = ''.join([t.text or '' for t in next_p.findall('.//w:t', ns)])
                    break

            figures.append({
                'rId': r_id,
                'caption': caption_text,
                'img_path': img_path,
                'alt_text': alt_text,
                # 'image_base64': img_data  # Optional: Remove this if you only want the file path or bytes
            })

    # Step 3: Verify which figures have captions starting with "Figure {d} or Figure {letters}"
    figures_verified_cleaned = []
    for fig in figures:
        caption = fig['caption']
        if caption.startswith("Figure"):
            match = re.search(r"Figure [A-Za-z0-9]+", caption)
            if match:
                figure_number = match.group(0)
                caption_after = caption.split(figure_number)[1].strip()
                figures_verified_cleaned.append({'rId': fig['rId'], 'img_path': fig['img_path'], 'alt_text': fig['alt_text'], 'caption': caption, 'html_caption': caption_after})

    # Step 4: Check for missing figures in the html
    missing_figures = {}
    soup = BeautifulSoup(html_content, 'html.parser')
    figure_tags = soup.find_all('figcaption')

    # Identify missing captions that are in the docx but not in the html
    for fig in figures_verified_cleaned:
        found = False
        for fig_tag in figure_tags:
            if fig['html_caption'] in fig_tag.text.replace("\r\n", " "):
                found = True
                break
        if not found:
            missing_figures[fig['rId']] = {
                "caption": fig['caption'].rstrip(), # Remove trailing whitespace
                "img_path": '/'.join(fig['img_path'].split('/')[1:]),  # Include image path for reference     
                "alt_text": fig['alt_text']  # Include alt text for reference      
            }


    print(missing_figures)
# Out:
# {'rId16': {'caption': 'Figure 6. Slope across the property.', 'img_path': 'media/image8.png', 'alt_text': ''}, 'rId17': {'caption': 'Figure 7. Infrastructure that occurs within and around the Pages Creek property.', 'img_path': 'media/image9.png', 'alt_text': ''}, 'rId18': {'caption': 'Figure 8. State-based mapped tenure of the Pages Creek property.', 'img_path': 'media/image10.png', 'alt_text': ''}, 'rId19': {'caption': 'Figure 9. State-based zoning of the Pages Creek property.', 'img_path': 'media/image11.png', 'alt_text': ''}, 'rId20': {'caption': 'Figure 10. Mapping of Indigenous Land Use Agreements in and native title determinations in and around the Pages Creek property.', 'img_path': 'media/image12.png', 'alt_text': ''}, 'rId21': {'caption': 'Figure 11. Mining tenements and exploration licenses in and around the Pages Creek property.', 'img_path': 'media/image13.png', 'alt_text': ''}, 'rId22': {'caption': 'Figure 12. Existing Clean Energy Regulator carbon projects in and around the Pages Creek property.', 'img_path': 'media/image14.png', 'alt_text': ''}, 'rId23': {'caption': 'Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024.', 'img_path': 'media/image15.png', 'alt_text': 'A graph of a number of months\n\nAI-generated content may be incorrect.'}, 'rId24': {'caption': 'Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', 'img_path': 'media/image16.png', 'alt_text': 'keep-chart-temperature'}, 'rId25': {'caption': 'Figure 15. Median number of days with temperatures below 0°C since 1956.', 'img_path': 'media/image17.png', 'alt_text': 'keep-chart-temperature'}, 'rId27': {'caption': 'Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', 'img_path': 'media/image19.png', 'alt_text': 'keep-chart-drought'}, 'rId29': {'caption': 'Figure 17. The bushfire history (prescribed burn and wildfire) in the region surrounding the Pages Creek property. The property boundaries are identified by the white bordered polygons.', 'img_path': 'media/image21.png', 'alt_text': ''}, 'rId31': {'caption': 'Figure 18. The probability of inundation for the region surrounding the Pages Creek property, based on a National Flood Risk Model.', 'img_path': 'media/image23.png', 'alt_text': ''}, 'rId32': {'caption': 'Figure 19. High risk areas of dryland salinity in the region surrounding the Pages Creek property', 'img_path': 'media/image24.png', 'alt_text': ''}, 'rId33': {'caption': 'Figure 20. Mapped Major Vegetation Groups (MVG) within the Pages Creek property', 'img_path': 'media/image25.png', 'alt_text': ''}, 'rId34': {'caption': 'Figure 21. State-based Pre-European vegetation within the Pages Creek property.', 'img_path': 'media/image26.png', 'alt_text': ''}, 'rId35': {'caption': 'Figure 22. Australian Soil Classification mapping within the Pages Creek property.', 'img_path': 'media/image27.png', 'alt_text': ''}, 'rId36': {'caption': 'Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', 'img_path': 'media/image28.png', 'alt_text': 'keep-image-timeline'}}

# %%
figures
# Out:
# [{'rId': 'rId11',
#   'caption': 'Figure 1. Location of the Pages Creek property in relation to surrounding localities. The property is identified by the white polygon.',
#   'img_path': 'word/media/image3.png',
#   'alt_text': ''},
#  {'rId': 'rId12',
#   'caption': 'Figure 2. a) Planting / non-woody areas of Pages Creek property; b) exclusion areas of Pages Creek as defined by grovia’s tree detection model.',
#   'img_path': 'word/media/image4.png',
#   'alt_text': ''},
#  {'rId': 'rId13',
#   'caption': 'Figure 3. Spatial distribution of carbon yield across the property.',
#   'img_path': 'word/media/image5.png',
#   'alt_text': ''},
#  {'rId': 'rId14',
#   'caption': 'Figure 4. CEA stratification and modelling points of Pages Creek property.',
#   'img_path': 'word/media/image6.png',
#   'alt_text': ''},
#  {'rId': 'rId15',
#   'caption': 'Figure 5. Accumulation curve of gross ACCUs generated each year over the 25-year permanence period. The first recommended reporting period of the permanence period is illustrated by a yellow star.',
#   'img_path': 'word/media/image7.png',
#   'alt_text': 'keep-chart-accu_curve'},
#  {'rId': 'rId16',
#   'caption': 'Figure 6. Slope across the property.',
#   'img_path': 'word/media/image8.png',
#   'alt_text': ''},
#  {'rId': 'rId17',
#   'caption': 'Figure 7. Infrastructure that occurs within and around the Pages Creek property.',
#   'img_path': 'word/media/image9.png',
#   'alt_text': ''},
#  {'rId': 'rId18',
#   'caption': 'Figure 8. State-based mapped tenure of the Pages Creek property.',
#   'img_path': 'word/media/image10.png',
#   'alt_text': ''},
#  {'rId': 'rId19',
#   'caption': 'Figure 9. State-based zoning of the Pages Creek property.',
#   'img_path': 'word/media/image11.png',
#   'alt_text': ''},
#  {'rId': 'rId20',
#   'caption': 'Figure 10. Mapping of Indigenous Land Use Agreements in and native title determinations in and around the Pages Creek property.',
#   'img_path': 'word/media/image12.png',
#   'alt_text': ''},
#  {'rId': 'rId21',
#   'caption': 'Figure 11. Mining tenements and exploration licenses in and around the Pages Creek property.',
#   'img_path': 'word/media/image13.png',
#   'alt_text': ''},
#  {'rId': 'rId22',
#   'caption': 'Figure 12. Existing Clean Energy Regulator carbon projects in and around the Pages Creek property.',
#   'img_path': 'word/media/image14.png',
#   'alt_text': ''},
#  {'rId': 'rId23',
#   'caption': 'Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024. ',
#   'img_path': 'word/media/image15.png',
#   'alt_text': 'A graph of a number of months\n\nAI-generated content may be incorrect.'},
#  {'rId': 'rId24',
#   'caption': 'Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.',
#   'img_path': 'word/media/image16.png',
#   'alt_text': 'keep-chart-temperature'},
#  {'rId': 'rId25',
#   'caption': 'Figure 15. Median number of days with temperatures below 0°C since 1956.',
#   'img_path': 'word/media/image17.png',
#   'alt_text': 'keep-chart-temperature'},
#  {'rId': 'rId27',
#   'caption': 'Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.',
#   'img_path': 'word/media/image19.png',
#   'alt_text': 'keep-chart-drought'},
#  {'rId': 'rId29',
#   'caption': 'Figure 17. The bushfire history (prescribed burn and wildfire) in the region surrounding the Pages Creek property. The property boundaries are identified by the white bordered polygons.',
#   'img_path': 'word/media/image21.png',
#   'alt_text': ''},
#  {'rId': 'rId31',
#   'caption': 'Figure 18. The probability of inundation for the region surrounding the Pages Creek property, based on a National Flood Risk Model.',
#   'img_path': 'word/media/image23.png',
#   'alt_text': ''},
#  {'rId': 'rId32',
#   'caption': 'Figure 19. High risk areas of dryland salinity in the region surrounding the Pages Creek property',
#   'img_path': 'word/media/image24.png',
#   'alt_text': ''},
#  {'rId': 'rId33',
#   'caption': 'Figure 20. Mapped Major Vegetation Groups (MVG) within the Pages Creek property',
#   'img_path': 'word/media/image25.png',
#   'alt_text': ''},
#  {'rId': 'rId34',
#   'caption': 'Figure 21. State-based Pre-European vegetation within the Pages Creek property.',
#   'img_path': 'word/media/image26.png',
#   'alt_text': ''},
#  {'rId': 'rId35',
#   'caption': 'Figure 22. Australian Soil Classification mapping within the Pages Creek property.',
#   'img_path': 'word/media/image27.png',
#   'alt_text': ''},
#  {'rId': 'rId36',
#   'caption': 'Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.',
#   'img_path': 'word/media/image28.png',
#   'alt_text': 'keep-image-timeline'},
#  {'rId': 'rId9',
#   'caption': '',
#   'img_path': 'word/media/image1.png',
#   'alt_text': ''},
#  {'rId': 'rId10',
#   'caption': 'Project Area:',
#   'img_path': 'word/media/image2.png',
#   'alt_text': 'keep-icon-material-symbols-outlined:psychiatry'},
#  {'rId': 'rId26',
#   'caption': '',
#   'img_path': 'word/media/image18.png',
#   'alt_text': 'keep-icon-custom:drought'},
#  {'rId': 'rId28',
#   'caption': '',
#   'img_path': 'word/media/image20.png',
#   'alt_text': 'keep-icon-custom:bushfire'},
#  {'rId': 'rId30',
#   'caption': '',
#   'img_path': 'word/media/image22.png',
#   'alt_text': 'keep-icon-custom:flood'},
#  {'rId': 'rId37',
#   'caption': '',
#   'img_path': 'word/media/image29.png',
#   'alt_text': 'last_page_logo'}]

# %%
figures
# Out:
# [{'rId': 'rId9',
#   'caption': '',
#   'img_path': 'word/media/image1.png',
#   'alt_text': ''},
#  {'rId': 'rId10',
#   'caption': 'Project Area:',
#   'img_path': 'word/media/image2.png',
#   'alt_text': ''},
#  {'rId': 'rId11',
#   'caption': 'Figure 1. Location of the Pages Creek property in relation to surrounding localities. The property is identified by the white polygon.',
#   'img_path': 'word/media/image3.png',
#   'alt_text': ''},
#  {'rId': 'rId12',
#   'caption': 'Figure 2. a) Planting / non-woody areas of Pages Creek property; b) exclusion areas of Pages Creek as defined by grovia’s tree detection model.',
#   'img_path': 'word/media/image4.png',
#   'alt_text': ''},
#  {'rId': 'rId13',
#   'caption': 'Figure 3. Spatial distribution of carbon yield across the property.',
#   'img_path': 'word/media/image5.png',
#   'alt_text': ''},
#  {'rId': 'rId14',
#   'caption': 'Figure 4. CEA stratification and modelling points of Pages Creek property.',
#   'img_path': 'word/media/image6.png',
#   'alt_text': ''},
#  {'rId': 'rId15',
#   'caption': 'Figure 5. Accumulation curve of gross ACCUs generated each year over the 25-year permanence period. The first recommended reporting period of the permanence period is illustrated by a yellow star.',
#   'img_path': 'word/media/image7.png',
#   'alt_text': ''},
#  {'rId': 'rId16',
#   'caption': 'Figure 6. Slope across the property.',
#   'img_path': 'word/media/image8.png',
#   'alt_text': ''},
#  {'rId': 'rId17',
#   'caption': 'Figure 7. Infrastructure that occurs within and around the Pages Creek property.',
#   'img_path': 'word/media/image9.png',
#   'alt_text': ''},
#  {'rId': 'rId18',
#   'caption': 'Figure 8. State-based mapped tenure of the Pages Creek property.',
#   'img_path': 'word/media/image10.png',
#   'alt_text': ''},
#  {'rId': 'rId19',
#   'caption': 'Figure 9. State-based zoning of the Pages Creek property.',
#   'img_path': 'word/media/image11.png',
#   'alt_text': ''},
#  {'rId': 'rId20',
#   'caption': 'Figure 10. Mapping of Indigenous Land Use Agreements in and native title determinations in and around the Pages Creek property.',
#   'img_path': 'word/media/image12.png',
#   'alt_text': ''},
#  {'rId': 'rId21',
#   'caption': 'Figure 11. Mining tenements and exploration licenses in and around the Pages Creek property.',
#   'img_path': 'word/media/image13.png',
#   'alt_text': ''},
#  {'rId': 'rId22',
#   'caption': 'Figure 12. Existing Clean Energy Regulator carbon projects in and around the Pages Creek property.',
#   'img_path': 'word/media/image14.png',
#   'alt_text': ''},
#  {'rId': 'rId23',
#   'caption': 'Figure 13. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. Average monthly precipitation (mm) over the year of the area surrounding the property using data from 1956 – 2024. ',
#   'img_path': 'word/media/image15.png',
#   'alt_text': ''},
#  {'rId': 'rId24',
#   'caption': 'Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.',
#   'img_path': 'word/media/image16.png',
#   'alt_text': ''},
#  {'rId': 'rId25',
#   'caption': 'Figure 15. Median number of days with temperatures below 0°C since 1956.',
#   'img_path': 'word/media/image17.png',
#   'alt_text': ''},
#  {'rId': 'rId26',
#   'caption': '',
#   'img_path': 'word/media/image18.png',
#   'alt_text': ''},
#  {'rId': 'rId27',
#   'caption': 'Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.',
#   'img_path': 'word/media/image19.png',
#   'alt_text': ''},
#  {'rId': 'rId28',
#   'caption': '',
#   'img_path': 'word/media/image20.png',
#   'alt_text': ''},
#  {'rId': 'rId29',
#   'caption': 'Figure 17. The bushfire history (prescribed burn and wildfire) in the region surrounding the Pages Creek property. The property boundaries are identified by the white bordered polygons.',
#   'img_path': 'word/media/image21.png',
#   'alt_text': ''},
#  {'rId': 'rId30',
#   'caption': '',
#   'img_path': 'word/media/image22.png',
#   'alt_text': ''},
#  {'rId': 'rId31',
#   'caption': 'Figure 18. The probability of inundation for the region surrounding the Pages Creek property, based on a National Flood Risk Model.',
#   'img_path': 'word/media/image23.png',
#   'alt_text': ''},
#  {'rId': 'rId32',
#   'caption': 'Figure 19. High risk areas of dryland salinity in the region surrounding the Pages Creek property',
#   'img_path': 'word/media/image24.png',
#   'alt_text': ''},
#  {'rId': 'rId33',
#   'caption': 'Figure 20. Mapped Major Vegetation Groups (MVG) within the Pages Creek property',
#   'img_path': 'word/media/image25.png',
#   'alt_text': ''},
#  {'rId': 'rId34',
#   'caption': 'Figure 21. State-based Pre-European vegetation within the Pages Creek property.',
#   'img_path': 'word/media/image26.png',
#   'alt_text': ''},
#  {'rId': 'rId35',
#   'caption': 'Figure 22. Australian Soil Classification mapping within the Pages Creek property.',
#   'img_path': 'word/media/image27.png',
#   'alt_text': ''},
#  {'rId': 'rId36',
#   'caption': 'Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.',
#   'img_path': 'word/media/image28.png',
#   'alt_text': ''},
#  {'rId': 'rId37',
#   'caption': '',
#   'img_path': 'word/media/image29.png',
#   'alt_text': ''}]

# %%
figure_captions
# Out:
# {'image7': Image(figure_number=5, figure_number_new=1, figure_caption='Figure 5. Accumulation curve of gross ACCUs generated\r\neach year over the 25-year permanence period. The first recommended\r\nreporting period of the permanence period is illustrated by a yellow\r\nstar.', alt_text='keep-chart-accu_curve')}

# %%
from collections import namedtuple


def retrieve_all_figure_captions(docx_path, html_content, doc_img_src):
    """
    Retrieve all figure captions from the HTML content and match them with the document images.
    
    Args:
        docx_path (str): Path to the DOCX file.
        html_content (str): The HTML content as a string.
        doc_img_src (list): List of image source paths from the document.

    Returns:
        dict: A dictionary mapping image names to their figure captions and alt texts.
    """
    Image = namedtuple('Image', ["figure_number", "figure_number_new", "figure_caption", "alt_text"])

    figure_captions_revised = {}
    if not len(figure_captions) == len(doc_img_src):
        print("⚠️ WARNING: Number of figure captions does not match number of images in the document.")
        print("Sourcing missing figures from document...")
        # missing_figures = dc.check_for_missing_figures(compatible_docx_path, initial_html_clean)
        missing_figures = check_for_missing_figures(docx_path, html_content)
        manual_sourcing_imgs = { os.path.splitext(os.path.basename(value['img_path']))[0]: key for key , value in missing_figures.items()}
        figure_counter = 1
        for image_path in doc_img_src:
            image_name = os.path.splitext(os.path.basename(image_path))[0]
            if image_name not in figure_captions.keys():
                if image_name in manual_sourcing_imgs:
                    r_Id = manual_sourcing_imgs[image_name]
                    figure_captions_revised[image_name] = Image(0, figure_counter, missing_figures[r_Id]['caption'], missing_figures[r_Id]['alt_text']) #Current figure number is 0 as it is unknown but could be grabbed from the caption
                    # result[current_img] = Image(figure_number, figure_number_new, figure_caption, alt_text)
                    figure_counter += 1
                else:
                    # figure_captions_revised[image_name] = f"Figure {image_name} caption not found."
                    print(f"⚠️ WARNING: Figure {image_name} caption not found.")
                    print("If it is an icon, then it doesn't matter, otherwise please check the document.")
            else:
                figure_captions_revised[image_name] = figure_captions[image_name]
                figure_counter += 1

    return figure_captions_revised
# Out:
# ⚠️ WARNING: Number of figure captions does not match number of images in the document.
# Sourcing missing figures from document...
# ⚠️ WARNING: Figure image2 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image18 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image20 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# ⚠️ WARNING: Figure image22 caption not found.
# If it is an icon, then it doesn't matter, otherwise please check the document.
# {'image8': 'rId16', 'image9': 'rId17', 'image10': 'rId18', 'image11': 'rId19', 'image12': 'rId20', 'image13': 'rId21', 'image14': 'rId22', 'image15': 'rId23', 'image16': 'rId24', 'image17': 'rId25', 'image19': 'rId27', 'image21': 'rId29', 'image23': 'rId31', 'image24': 'rId32', 'image25': 'rId33', 'image26': 'rId34', 'image27': 'rId35', 'image28': 'rId36'}

# %%
figure_captions_revised
# Out:
# {'image7': Image(figure_number=5, figure_number_new=1, figure_caption='Figure 5. Accumulation curve of gross ACCUs generated\r\neach year over the 25-year permanence period. The first recommended\r\nreporting period of the permanence period is illustrated by a yellow\r\nstar.', alt_text='keep-chart-accu_curve'),
#  'image16': Image(figure_number=0, figure_number_new=2, figure_caption='Figure 14. Interpolated climate data from the Bureau of Meteorology and other providers at a 5km resolution. The figure shows the mean minimum and mean maximum monthly temperatures from data between 1956 to 2024.', alt_text='keep-chart-temperature'),
#  'image17': Image(figure_number=0, figure_number_new=3, figure_caption='Figure 15. Median number of days with temperatures below 0°C since 1956.', alt_text='keep-chart-temperature'),
#  'image19': Image(figure_number=0, figure_number_new=4, figure_caption='Figure 16. The Standardised Precipitation Evapotranspiration Index data for the past 20 years, grouped by 6 months, of the region surrounding the Pages Creek property.', alt_text='keep-chart-drought'),
#  'image28': Image(figure_number=0, figure_number_new=5, figure_caption='Figure 23. A timeline outlining the key stages of a carbon project, from due diligence, site visit and document preparation, to CER project registration, establishment and ongoing monitoring, reporting, and verification post-planting.', alt_text='keep-image-timeline')}

# %% [markdown]
# New version
