# %% [markdown]
# #### Basic navigation
#
# Features:
#  - Formatted text
#  - Formatted tables including cell bg colour and horizontal merging
#  - Targetted image retrieval

# %%
import docx_converter as dc
from docx import Document
import os
import pypandoc
import os
import shutil
import json
import re
from collections import Counter

# %%
import importlib

dc = importlib.reload(dc)

# %% [markdown]
# #### Testing

# %%
# Define system-wide defaults as a simple dictionary
GLOBAL_DEFAULT_STYLES = {
    "textAlign": "left",
    "fontSize": "1rem",  # 16px converted to rem
    "fontWeight": "normal",
    "color": "#000000",
    "backgroundColor": "#FFFFFF",
    "padding": "8px",  # 5px converted to rem
    "verticalAlign": "middle"
}

## when there are multiple styles, the first one is the defaults
## This should not be the case for table cells where some text is bold and some is not or superscript for example
# { "text": "High risk. Only 4 ACCUs/ha2", 
# "fontWeight": "bold",
# "superscript": True}
## becomes 
# {
#     "textParts": [
#     { "text": "High risk.", "bold": true },
#     { "text": " Only 4 ACCUs/ha." },
#     { "text": "2", "superscript": true }
#     ]
# }

doc_path = "data/grovia_Carbon-PRO_Template.docx"


doc = Document(doc_path)
## Extract text and table styles
DEFAULT_STYLES = dc.extract_styles(doc_path)
dc.extract_table_format(doc_path, DEFAULT_STYLES)
# Out:
# {'table_0': {'headers': [{'text': 'Item assessed',
#     'textAlign': 'left',
#     'verticalAlign': 'middle'},
#    {'text': 'Assessment', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#   'rows': [[{'text': 'Planting Area',
#      'textAlign': 'left',
#      'verticalAlign': 'middle'},
#     {'textParts': [{'text': 'Moderate risk.', 'bold': True},
#       {'text': ' Lots of risk'},
#       {'text': '.'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#FFF7ED'}],
#    [{'text': 'Carbon returns', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'textParts': [{'text': 'High risk.', 'bold': True},
#       {'text': ' Only 4 ACCUs/ha.'}],
#      'textAlign': 'left',
#      'verticalAlign': 'top',
#      'backgroundColor': '#FEF2F2'}],
#    [{'text': 'Topography', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'textParts': [{'text': 'Low risk', 'bold': True},
#       {'text': '. ', 'bold': True},
#       {'text': 'Little to no areas with slope greater than 15 degrees.'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F7FEE7'}]]},
#  'table_1': {'headers': [{'textParts': [{'text': 'Attribute',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'textParts': [{'text': 'Details', 'bold': True, 'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'}],
#   'rows': [[{'text': 'Property Name',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': 'PROP-002194, King Parrot',
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': 'Property '}, {'text': 'S'}, {'text': 'ize'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '172.94ha', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Address / Location',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'textParts': [{'text': 'Somewhere, '}, {'text': 'VIC'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'text': 'LGA',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': 'Murrindindi', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Planting Area',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '52 ha', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': 'Ineligible Area'},
#       {'text': '', 'superscript': True}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '105 ha', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Total ACCUs generated (gross)',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '2500 ACCUs', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': 'Total A'},
#       {'text': 'CC'},
#       {'text': 'Us (net) - for 25 years*'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '120210 ACCUs', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Total ACCUs (net) - for 100 years**',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '21021 ACCUs', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Tenure',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'textParts': [{'text': 'Freehold: 105ha'},
#       {'text': 'Other Crown Purposes: 50ha'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': 'Köppen'},
#       {'text': ' '},
#       {'text': 'C'},
#       {'text': 'limate '},
#       {'text': 'C'},
#       {'text': 'lassification'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'textParts': [{'text': 'Temperat'},
#       {'text': 'e: '},
#       {'text': 'no dry season (warm summer)'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'text': 'Average Rainfall',
#      'textAlign': 'left',
#      'verticalAlign': 'top',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '704 mm (Appendix A, Figure A1)',
#      'textAlign': 'left',
#      'verticalAlign': 'top'}],
#    [{'text': 'Frost Potential',
#      'textAlign': 'left',
#      'verticalAlign': 'top',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '10 days/year (Appendix A, Figure A3)',
#      'textAlign': 'left',
#      'verticalAlign': 'top'}],
#    [{'textParts': [{'text': '* Inclusive of 20% permanence period discount and 5% risk of reversal buffer'},
#       {'text': '** Inclusive of 5% risk of reversal buffer'}],
#      'colSpan': 2,
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'}]]},
#  'table_2': {'headers': [{'textParts': [{'text': 'Category',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'textParts': [{'text': 'Total Area (ha)',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'textParts': [{'text': 'Percent Cover (%)',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'}],
#   'rows': [[{'text': 'Non-woody (eligible)',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '148.66', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '85.96', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Non-woody (ineligible)*',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '0.31', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '0.18', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Sparse woody vegetation',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '16.65', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '9.63', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Woody vegetation (forest)',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '7.31', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '4.23', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Total',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '172.93', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '100.00', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': '* The National Forest and Sparse Woody Vegetation data indicates that woody vegetation loss has likely occurred in the past 7 years.',
#      'colSpan': 3,
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'}]]},
#  'table_3': {'headers': [{'textParts': [{'text': 'Parameter',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'textParts': [{'text': 'ACCUs', 'bold': True, 'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'}],
#   'rows': [[{'textParts': [{'text': 'Project average'},
#       {'text': ' per hectare'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '212', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Project total (Gross)',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '26,772', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Project total (Net)',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'textParts': [], 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': '├─'},
#       {'text': ' '},
#       {'text': '100'},
#       {'text': '-'},
#       {'text': 'y'},
#       {'text': 'ear '},
#       {'text': 'p'},
#       {'text': 'ermanence'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '25,433', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': '├─'},
#       {'text': ' '},
#       {'text': '25'},
#       {'text': '-'},
#       {'text': 'y'},
#       {'text': 'ear '},
#       {'text': 'p'},
#       {'text': 'ermanence'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '20,079', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': 'Key Action:', 'bold': True},
#       {'text': ' A site visit is required to refine the planting area and determine other factors that may result in further CEA stratification before re-running a method compliant '},
#       {'text': 'FullCAM'},
#       {'text': ' assessment.'}],
#      'colSpan': 2,
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'}]]},
#  'table_4': {'headers': [{'textParts': [{'text': 'CEA',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'textParts': [{'text': 'Yield (tCO2/ha)',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'textParts': [{'text': 'Description', 'bold': True, 'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'}],
#   'rows': [[{'text': '1',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '200', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': 'Sodosols with flat terrain',
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'text': '2-3',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '367', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': 'Chromosols with flat terrain',
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'text': '4',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '221', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'textParts': [{'text': 'Chromosols on steep south facing'},
#       {'text': ' gentle'},
#       {'text': ' slopes.'}],
#      'textAlign': 'left',
#      'verticalAlign': 'middle'}],
#    [{'textParts': [{'text': 'Key Action:', 'bold': True},
#       {'text': ' A site visit is required to refine the planting area and determine other factors that may result in further CEA stratification before re-running a method compliant '},
#       {'text': 'FullCAM'},
#       {'text': ' assessment.'}],
#      'colSpan': 3,
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'}]]},
#  'table_5': {'headers': [{'text': 'Year',
#     'textAlign': 'left',
#     'verticalAlign': 'top'},
#    {'text': 'Cumulative ACCUs', 'textAlign': 'left', 'verticalAlign': 'top'},
#    {'text': 'Annual ACCUs issuance',
#     'textAlign': 'left',
#     'verticalAlign': 'top'}],
#   'rows': [[{'text': '1', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '482', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '482', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '2', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,442', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '960', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '3', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '2,865', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,423', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '4', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '4,525', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,660', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '5', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '6,268', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,743', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '6', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '7,997', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,729', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '7', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '9,676', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,679', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '8', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '11,256', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,580', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '9', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '12,753', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,497', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '10', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '14,153', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,400', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '11', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '15,456', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,303', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '12', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '16,675', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,219', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '13', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '17,811', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,136', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '14', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '18,863', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '1,052', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '15', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '19,846', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '983', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '16', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '20,764', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '918', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '17', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '21,617', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '853', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '18', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '22,419', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '802', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '19', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '23,165', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '746', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '20', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '23,865', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '700', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '21', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '24,523', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '658', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '22', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '25,135', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '612', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '23', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '25,714', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '579', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '24', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '26,257', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '543', 'textAlign': 'left', 'verticalAlign': 'top'}],
#    [{'text': '25', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '26,772', 'textAlign': 'left', 'verticalAlign': 'top'},
#     {'text': '515', 'textAlign': 'left', 'verticalAlign': 'top'}]]},
#  'table_6': {'headers': [{'text': 'Slope (degrees)',
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'text': 'Planting Area (ha)',
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'},
#    {'text': 'Planting Area (%)',
#     'textAlign': 'left',
#     'verticalAlign': 'middle',
#     'backgroundColor': '#1D426F'}],
#   'rows': [[{'text': '0 - 10',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '46.51', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '28.14', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': '10 - 15',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '38.28', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '23.16', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': '15 - 20',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '32.59', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '19.71', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': '20 - 30',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '43.63', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '26.39', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': '>= 30',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '4.30', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '2.60', 'textAlign': 'left', 'verticalAlign': 'middle'}],
#    [{'text': 'Total',
#      'textAlign': 'left',
#      'verticalAlign': 'middle',
#      'backgroundColor': '#F2F2F2'},
#     {'text': '165.31', 'textAlign': 'left', 'verticalAlign': 'middle'},
#     {'text': '100.00', 'textAlign': 'left', 'verticalAlign': 'middle'}]]},
#  'table_7': {'headers': [{'textParts': [{'text': 'Common name',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'bottom',
#     'backgroundColor': '#1D446F'},
#    {'textParts': [{'text': 'Scientific name',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'bottom',
#     'backgroundColor': '#1D446F'},
#    {'textParts': [{'text': 'Growth form', 'bold': True, 'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'bottom',
#     'backgroundColor': '#1D446F'},
#    {'textParts': [{'text': 'WONS', 'bold': True, 'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'bottom',
#     'backgroundColor': '#1D446F'},
#    {'textParts': [{'text': 'Biosecurity duty (Goulburn Broken CMA)',
#       'bold': True,
#       'color': '#FFFFFF'}],
#     'textAlign': 'left',
#     'verticalAlign': 'bottom',
#     'backgroundColor': '#1D446F'}],
#   'rows': [[{'text': 'African boxthorn',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Lycium'},
#       {'text': ' '},
#       {'text': 'ferocissimum'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'African daisy', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Senecio '}, {'text': 'pterophorus'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'African feather grass',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Cenchrus '}, {'text': 'macrourus'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Grass', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'African lovegrass',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Eragrostis'}, {'text': ' '}, {'text': 'curvula'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Grass', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Amsinckia', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Amsinckia'}, {'text': ' '}, {'text': 'calycina'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Artichoke thistle',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Cynara cardunculus',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Blackberry', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Rubus '}, {'text': 'fruticosus'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Boneseed', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Chrysanthemoides'},
#       {'text': ' '},
#       {'text': 'monilifera'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Buffalo burr', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Solanum '}, {'text': 'rostratum'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Caltrop', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Tribulus terrestris',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Cape tulip (one-leaf)',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Moraea'}, {'text': ' '}, {'text': 'flaccida'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Cape tulip (two-leaf)',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Moraea'}, {'text': ' miniata'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Chilean cestrum',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Cestrum '}, {'text': 'parqui'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Chilean needle grass',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Nassella'}, {'text': ' '}, {'text': 'neesiana'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Grass', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': "Devil's claw (purple flower)",
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Proboscidea '}, {'text': 'louisianica'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': "Devil's claw (yellow flower)",
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Proboscidea fragrans',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'English broom', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Cytisus'}, {'text': ' '}, {'text': 'scoparius'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Flax-leaved broom',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Genista '}, {'text': 'linifolia'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Golden thistle', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Scolymus '}, {'text': 'hispanicus'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Gorse', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Ulex europaeus', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Hardheads', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Centaurea nigra',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Illyrian thistle',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Onopordum'},
#       {'text': ' '},
#       {'text': 'illyricum'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Khaki weed', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Alternanthera '}, {'text': 'pungens'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'textParts': [{'text': 'Noogoora'}, {'text': ' burr'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Xanthium occidentale',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Paterson’s curse',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Echium '}, {'text': 'plantagineum'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Prairie ground cherry',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Physalis '}, {'text': 'hederifolia'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Prickly pear (drooping)',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Opuntia stricta',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Prickly pear (erect)',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Opuntia elatior',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Ragwort', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Jacobaea vulgaris',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Scotch thistle', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Onopordum'},
#       {'text': ' '},
#       {'text': 'acanthium'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Serrated tussock',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Nassella'},
#       {'text': ' '},
#       {'text': 'trichotoma'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Grass', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally prohibited',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Silverleaf nightshade',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Solanum '}, {'text': 'elaeagnifolium'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Skeleton weed', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Chondrilla'}, {'text': ' juncea'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Soldier thistle',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Cirsium vulgare',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Spiny broom', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Calicotome'}, {'text': ' spinosa'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Spiny burr grass',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Cenchrus '}, {'text': 'longispinus'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Grass', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'textParts': [{'text': 'Spiny '}, {'text': 'emex'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Emex'}, {'text': ' australis'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Star thistle', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Centaurea '}, {'text': 'calcitrapa'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Stemless thistle',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Cirsium '}, {'text': 'acaule'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': "St Barnaby's thistle",
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'textParts': [{'text': 'Centaurea '}, {'text': 'solstitialis'}],
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}],
#    [{'text': 'Thorn apple (recurved)',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Datura stramonium',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Herb', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'N', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Regionally controlled',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'}],
#    [{'text': 'Wheel cactus', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Opuntia robusta',
#      'textAlign': 'left',
#      'verticalAlign': 'bottom'},
#     {'text': 'Shrub', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Y', 'textAlign': 'left', 'verticalAlign': 'bottom'},
#     {'text': 'Restricted', 'textAlign': 'left', 'verticalAlign': 'bottom'}]]}}

# %%
doc_path = "data/grovia_Carbon-PRO_Template.docx"
output_path = f"app/{os.path.splitext(os.path.basename(doc_path))[0]}"
lua_script = "scripts/pandoc/docx_cleanup.lua"

os.makedirs(output_path, exist_ok=True)
allowed_alt_texts = ["timeline"]

os.makedirs(f"{output_path}/{dc.FOLDERS['media']}", exist_ok=True)
os.makedirs(f"{output_path}/{dc.FOLDERS['data']}", exist_ok=True)
os.makedirs(f"{output_path}/{dc.FOLDERS['content']}", exist_ok=True)


## copy index.html to output_path
shutil.copyfile("scripts/index.html", f"{output_path}/index.html")
if not os.path.exists(f"{output_path}/js"):
    shutil.copytree("scripts/js", f"{output_path}/js")
if not os.path.exists(f"{output_path}/css"):
    shutil.copytree("scripts/css", f"{output_path}/css")

## Extract text and table styles
DEFAULT_STYLES = dc.extract_styles(doc_path)
## save to json
with open(f"{output_path}/{dc.FOLDERS['data']}/styles.json", 'w') as f:
    json.dump(DEFAULT_STYLES, f, indent=2)

## Extract table formating that differs from the default styles
tables = dc.extract_table_format(doc_path, DEFAULT_STYLES)
## save to json
with open(f'{output_path}/{dc.FOLDERS['data']}/tables.json', 'w') as f:
    json.dump(tables, f, indent=2)

alt_text_map = dc.extract_docx_media(doc_path, output_path, dc.FOLDERS['media'], allowed_alt_texts)
print("\n📝 Alt Text to Image Mapping:", alt_text_map)
## convert to a list of image integers
keep_images = [int(name.replace('image', '').replace('.png', '')) for name in alt_text_map.keys()]
images_dict = {image: {'path': path, 'alt_text': ''} for image, path in alt_text_map.items()}
print(images_dict)

## Generate HTML from the docx file
html = dc.convert_docx_to_html(doc_path, lua_script, keep_images)
print("HTML with unwanted images removed has been generated.")

# Replace images with placeholders
html_images, alt_text_map = dc.replace_images_with_placeholders(html, images_dict)

## Save to json
with open(f'{output_path}/{dc.FOLDERS['data']}/media.json', 'w') as f:
    json.dump(alt_text_map, f, indent=2)

# Regular expression to match tables
table_pattern = re.compile(r'<table.*?</table>', re.DOTALL)

# Reset the counter to zero before replacing tables
counter = [0]
html_tables_id = table_pattern.sub(lambda match: dc.table_replacer(match, counter), html_images)

# Generate navigation data
nav_data = dc.generate_navigation_data(html_tables_id)

# Save navigation data to JSON file
with open(f"{output_path}/{dc.FOLDERS['data']}/navigation.json", "w", encoding="utf-8") as f:
    json.dump(nav_data, f, indent=4)


# Embed navigation data placeholder as the first element in the HTML
if '<div data-navigation></div>' not in html_tables_id:
    content_html = '<div data-navigation></div>\n' + html_tables_id

# Embed sub navigation data placeholder in the HTML. Place at the line above the first h2 tag of each section
content_html = dc.insert_sub_navigation(content_html, nav_data)


# Save the modified content.html
with open(f"{output_path}/{dc.FOLDERS['content']}/content.html", "w", encoding="utf-8") as f:
    f.write(content_html)

print("Navigation JSON file and content placeholder updated successfully!")
print(f"Conversion complete! HTML file saved as {output_path}.")
# Out:
# ✅ Moving image: image2.png ➝ app/grovia_Carbon-PRO_Template\assets\image2.png
# ✅ Moving image: image5.png ➝ app/grovia_Carbon-PRO_Template\assets\image5.png
# ✅ Moving image: image22.png ➝ app/grovia_Carbon-PRO_Template\assets\image22.png
#
# 📝 Alt Text to Image Mapping: {'image2': 'assets/image2.png', 'image5': 'assets/image5.png', 'image22': 'assets/image22.png'}
# {'image2': {'path': 'assets/image2.png', 'alt_text': ''}, 'image5': {'path': 'assets/image5.png', 'alt_text': ''}, 'image22': {'path': 'assets/image22.png', 'alt_text': ''}}
# HTML with unwanted images removed has been generated.
# Navigation JSON file and content placeholder updated successfully!
# Conversion complete! HTML file saved as app/grovia_Carbon-PRO_Template.
